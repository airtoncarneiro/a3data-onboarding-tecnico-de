# %% [markdown]
# # TESTE PRÁTICO DE LINGUAGEM DE CONSULTA ESTRUTURADA (SQL)
# Para a realização das atividades, você deverá executar as instruções abaixo para importar as bibliotecas e funções necessárias para criar a base de dados.
#
# Ao final, esperamos que você desenvolva os códigos selecionados e entregue o notebook com as consultas SQL desenvolvidas e o arquivo .db criado.
#
# O teste importará três arquivos cruciais para o desenvolvimento dessa atividade. Todos estão no Githun (não mude as URL's).
#
# *   usuarios.csv
# *   produtos.csv
# *   vendas.csv
#
# ## O teste foi desenvolvido para ser executado com o SQLite3 e no Google Colab (Ubuntu 18.04). Você deverá utilizar consultas no padrão ANSI. Os comandos necessários podem ser encontrados em:
#
# https://www.sqlite.org/docs.html
#
# https://www.tutorialspoint.com/sqlite/index.htm

# %% [markdown]
# # AVISO!
#
#
#
# 1.   Execute o código abaixo para atualizar a biblioteca do SQLite3 utilizada para essa atividade
# 2.   **Ignore as mensagens de erro sobre perda de conectividade na instrução abaixo (o kernel será reiniciado para atualização do SQLite3)**

# %%
import os

# BAIXAR A ÚLTIMA RELEASE DO COLAB, DESCOMPACTAR E INSTALAR NO DIRETÓRIO DO 
# PYTHON 3.7 (VERSÃO USADA PELO COLAB NESSE NOTEBOOK)
# !curl https://www.sqlite.org/src/tarball/sqlite.tar.gz?r=release | tar xz
# %cd sqlite/
# !./configure
# !make sqlite3.c
# %cd /content/sqlite/
# !npx degit coleifer/pysqlite3 -f
# !cp sqlite/sqlite3.[ch] .
# !python setup.py build_static build
# !cp build/lib.linux-x86_64-3.7/pysqlite3/_sqlite3.cpython-37m-x86_64-linux-gnu.so \
     /usr/lib/python3.7/lib-dynload/

# REINICIANDO O KERNEL DO COLAB PARA IMPORTAR A BIBLIOTECA ATUALIZADA
os.kill(os.getpid(), 9)

# %% [markdown]
# # INSTRUÇÕES PARA REALIZAR AS CONSULTAS
# ### PARA CONSULTAR DADOS, SIGA OS PASSOS ABAIXO:
#
# #### Abrir conexão:
#     conexao_sql = sqlite3.connect(banco)
# #### Abrir cursor para executar consulta no banco:
#     cursor = conexao_sql.cursor()
# #### Criar uma consulta:
#     consulta = '''
#         Coloque aqui a sua instrução SQL;
#     '''
#     cursor.execute(consulta)
# #### Para visualizar o resultado da sua consulta:
#     for linha in cursor:
#       print(linha)
# #### Para fechar a conexão:
#     conexao_sql.close()
#
# ### LEMBRE-SE DE QUE PYTHON É SENSÍVEL A IDENTAÇÃO DE CÓDIGO!

# %% [markdown]
# # IMPORTANDO BIBLIOTECAS NECESSÁRIAS PARA EXECUTAR OS CÓDIGOS EM SQL

# %%
import sqlite3
import csv
import requests
from pathlib import Path
from urllib.parse import urlparse

# %% [markdown]
# # DEFINIÇÃO DE VARIÁVEIS FIXAS PARA O PROJETO

# %%
banco = "teste_sql.db"

# %% [markdown]
# # FUNÇÃO PARA INSERIR REGISTROS NO BANCO DE DADOS

# %%
# Recebe como parâmetro
# 1. Nome do banco de dados
# 2. Nome da tabela que receberá os dados
# 3. Lista das colunas da tabela
# 4. Dados que serão inseridos

def inserir_registros(banco, tabela, lista_colunas, arquivo):
  conexao_sql = sqlite3.connect(banco)
  cursor = conexao_sql.cursor()
  dados = open(arquivo)
  conteudo_dados = csv.reader(dados)
  num_colunas = 1 if lista_colunas.count(',') == 1 else lista_colunas.count(',')
  string_insert = 'INSERT INTO ' + tabela + ' (' + lista_colunas + ') VALUES (?' + ('' if num_colunas == 1 else ', ?' * (num_colunas)) + ')'
  cursor.executemany(string_insert, conteudo_dados)
  conexao_sql.commit()
  conexao_sql.close()

# %% [markdown]
# # FUNÇÃO PARA BAIXAR A BASE DE DADOS UTILIZADA PARA DESENVOLVIMENTO DAS ATIVIDADES

# %%
# Recebe como parâmetro:
# 1. Nome do arquivo com a extensão (Ex: base.csv)
# 2. URL do site onde o dado está localizado (Ex: 'https://drive.google.com/user_teste/folder_dataset/file.csv'):

def baixar_dados(nome_arquivo, url):
  requisicao = requests.get(url)
  conteudo = requisicao.content
  arquivo_csv = open(nome_arquivo, 'wb')
  arquivo_csv.write(conteudo)
  arquivo_csv.close()

# %% [markdown]
# # CRIAÇÃO DE CONEXÃO COM O BANCO SQLITE3 PARA DESENVOLVIMENTO DA ATIVIDADE

# %%
# Abre conexão com o banco. Se o arquivo não existir, cria a base.
conexao_sql = sqlite3.connect(banco)
conexao_sql.close()

# %% [markdown]
# # CRIAÇÃO DAS TABELAS PARA REALIZAÇÃO DAS ATIVIDADES

# %% [markdown]
# ### TABELA DE USUÁRIOS

# %%
url = 'https://raw.githubusercontent.com/A3Data/testes_praticos/main/sql/base_dados/usuarios.csv'
nome_arquivo = Path(urlparse(url).path).name
baixar_dados(nome_arquivo, url)

conexao_sql = sqlite3.connect(banco)
# CRIAR A TABELA
conexao_sql.execute('''
CREATE TABLE IF NOT EXISTS usuarios
(
  cod_usuario INTEGER NOT NULL,
  data_cadastro DATE NOT NULL,
  faixa_etaria TEXT,
  cidade TEXT NOT NULL,
  estado TEXT NOT NULL);'''
)
conexao_sql.commit()

# INSERIR OS REGISTROS NO BANCO DE DADOS
lista_campos = 'cod_usuario, data_cadastro, faixa_etaria, cidade, estado'
inserir_registros(banco, 'usuarios', lista_campos, nome_arquivo)

# %% [markdown]
# ### TABELA DE PRODUTOS

# %%
url = 'https://raw.githubusercontent.com/A3Data/testes_praticos/main/sql/base_dados/produtos.csv'
nome_arquivo = Path(urlparse(url).path).name
baixar_dados(nome_arquivo, url)

conexao_sql = sqlite3.connect(banco)
arquivo_produtos = 'produtos.csv'
# CRIAR A TABELA
conexao_sql.execute('''
CREATE TABLE IF NOT EXISTS produtos
(
  cod_produto INTEGER NOT NULL,
  nome_produto TEXT NOT NULL,
  categoria_produto TEXT,
  valor_produto FLOAT);'''
)
conexao_sql.commit()

# INSERIR OS REGISTROS NO BANCO DE DADOS
lista_campos = 'cod_produto, nome_produto, categoria_produto, valor_produto'
inserir_registros(banco, 'produtos', lista_campos, arquivo_produtos)

# %% [markdown]
# ### TABELA DE VENDAS

# %%
url = 'https://raw.githubusercontent.com/A3Data/testes_praticos/main/sql/base_dados/vendas.csv'
nome_arquivo = Path(urlparse(url).path).name
baixar_dados(nome_arquivo, url)

conexao_sql = sqlite3.connect(banco)
arquivo_vendas = 'vendas.csv'
# CRIAR A TABELA
conexao_sql.execute('''
CREATE TABLE IF NOT EXISTS vendas
(
  cod_usuario INTEGER NOT NULL,
  cod_produto INTEGER NOT NULL,
  data_compra DATE NOT NULL,
  quantidade INT NOT NULL,
  valor FLOAT NOT NULL);'''
)
conexao_sql.commit()

# INSERIR OS REGISTROS NO BANCO DE DADOS
lista_campos = 'cod_usuario, cod_produto, data_compra, quantidade, valor'
inserir_registros(banco, 'vendas', lista_campos, arquivo_vendas)

# %% [markdown]
# # PERGUNTA 1:
#
# ### Escreva um comando em SQL que retorne a quantidade de vendas dos estados de Minas Gerais e São Paulo por ano e mês

# %%
#
# Criando uma função para executar o cursor via context manager
#
# (esta importação, claro, estaria no início)
from contextlib import contextmanager

@contextmanager
def execute_query(query):
    with sqlite3.connect(banco) as conexao_sql:
        c = conexao_sql.cursor()
        c.execute(query)
        yield c
        c.close()

# %%
query = '''
    SELECT u.estado,
           strftime('%Y-%m', v.data_compra),
           sum(quantidade) qtd_vendas
      FROM vendas v
      JOIN usuarios u ON
        u.cod_usuario = v.cod_usuario
      WHERE u.estado IN ('São Paulo', 'Minas Gerais')
      GROUP BY u.estado, strftime('%Y-%m', v.data_compra)
'''

with execute_query(query) as rows:
  for row in rows:
    print(row)
# Out:
# ('Minas Gerais', '2018-06', 10)
# ('Minas Gerais', '2018-08', 16)
# ('Minas Gerais', '2018-10', 20)
# ('Minas Gerais', '2018-11', 10)
# ('Minas Gerais', '2018-12', 39)
# ('Minas Gerais', '2019-01', 20)
# ('Minas Gerais', '2019-02', 2)
# ('Minas Gerais', '2019-04', 26)
# ('Minas Gerais', '2019-05', 11)
# ('Minas Gerais', '2019-06', 1)
# ('Minas Gerais', '2019-07', 14)
# ('Minas Gerais', '2019-08', 15)
# ('Minas Gerais', '2019-09', 27)
# ('Minas Gerais', '2019-10', 3)
# ('Minas Gerais', '2019-11', 1)
# ('Minas Gerais', '2019-12', 25)
# ('Minas Gerais', '2020-01', 8)
# ('Minas Gerais', '2020-02', 10)
# ('Minas Gerais', '2020-03', 14)
# ('Minas Gerais', '2020-04', 1)
# ('Minas Gerais', '2020-05', 44)
# ('Minas Gerais', '2020-06', 18)
# ('Minas Gerais', '2020-07', 30)
# ('Minas Gerais', '2020-09', 44)
# ('Minas Gerais', '2020-10', 8)
# ('Minas Gerais', '2020-11', 43)
# ('Minas Gerais', '2020-12', 18)
# ('Minas Gerais', '2021-01', 21)
# ('Minas Gerais', '2021-02', 75)
# ('Minas Gerais', '2021-03', 6)
# ('Minas Gerais', '2021-04', 58)
# ('Minas Gerais', '2021-05', 22)
# ('Minas Gerais', '2021-06', 16)
# ('Minas Gerais', '2021-07', 61)
# ('São Paulo', '2018-07', 9)
# ('São Paulo', '2018-10', 12)
# ('São Paulo', '2019-06', 10)
# ('São Paulo', '2019-08', 17)
# ('São Paulo', '2020-01', 6)
# ('São Paulo', '2020-03', 1)
# ('São Paulo', '2020-04', 9)
# ('São Paulo', '2020-06', 13)
# ('São Paulo', '2020-09', 22)
# ('São Paulo', '2020-10', 41)
# ('São Paulo', '2021-02', 15)
# ('São Paulo', '2021-03', 1)
# ('São Paulo', '2021-04', 28)
# ('São Paulo', '2021-05', 22)
# ('São Paulo', '2021-06', 56)
# ('São Paulo', '2021-07', 96)

# %% [markdown]
# # PERGUNTA 2:
#
# ### Escreva um comando em SQL que retorne o ticket médio (valor médio de compra) e quantidade de compras realizadas dos usuários que fizeram compras entre 2019 e 2020 e que tiveram mais de 3 compras no período (lembre-se de contar todas as compras dos usuários que estão nessa condição!)

# %%
query = '''
    SELECT u.cod_usuario,
           ROUND(AVG(valor),2) avg_compra, 
           count(1) qtd_compras
      FROM vendas v
      JOIN usuarios u
        ON u.cod_usuario = v.cod_usuario
      WHERE v.data_compra BETWEEN '2019-01-01' AND '2020-12-31'
      GROUP BY u.cod_usuario
      HAVING COUNT(1) > 3
'''

with execute_query(query) as rows:
  for row in rows:
    print(row)
# Out:
# (69, 25926.09, 4)
# (89, 22791.03, 4)
# (176, 1686.69, 5)
# (191, 1971.87, 4)
# (441, 2147.87, 6)
# (700, 21861.0, 6)
# (796, 1696.88, 4)
# (898, 3710.48, 4)
# (1074, 21402.8, 7)
# (1192, 2565.63, 4)
# (1415, 210.56, 6)
# (1696, 252.88, 6)
# (1752, 13832.69, 7)
# (1756, 24269.69, 5)
# (1787, 15756.61, 7)
# (1947, 14866.73, 4)
# (2183, 1482.16, 5)
# (2340, 22284.58, 6)
# (2392, 8185.07, 4)
# (2438, 17550.01, 5)
# (2551, 17265.39, 6)
# (2597, 8681.9, 4)
# (2646, 12171.34, 5)
# (2669, 6578.05, 4)
# (2811, 20773.65, 4)
# (2843, 16535.01, 8)
# (2856, 13890.9, 5)
# (2920, 15125.48, 5)
# (2981, 21811.9, 5)
# (3090, 13108.06, 7)
# (3358, 27187.44, 5)
# (3403, 14547.95, 8)

# %% [markdown]
# # PERGUNTA 3:
#
# ### Escreva um comando em SQL que retorne quais são os usuários por estado que mais compraram em todo o período analisado e, o número de compras realizadas, a quantidade total de itens comprados e valor total pago

# %%
# limitando aos 5 maiores compradores de cada estado.
# alterar o limite, caso necessário.
query = '''
  SELECT estado,
         cod_usuario,
         sum_compras,
         qtd_compras
    FROM (
      SELECT u.estado,
            u.cod_usuario,
            ROUND(SUM(valor),2) sum_compras,
            count(1) qtd_compras,
            row_number() over (partition by u.estado order by count(1) DESC) as rank    
        FROM vendas v
        JOIN usuarios u
          ON u.cod_usuario = v.cod_usuario
      GROUP BY u.estado, u.cod_usuario
    ) AS rank
  WHERE rank <= 5
'''

with execute_query(query) as rows:
    for row in rows:
        print(row)
# Out:
# ('Amapá', 2186, 51359.34, 7)
# ('Bahia', 2981, 126282.4, 9)
# ('Bahia', 2856, 71986.05, 7)
# ('Bahia', 3400, 7052.29, 5)
# ('Bahia', 176, 8433.46, 5)
# ('Bahia', 2155, 13820.4, 4)
# ('Ceará', 1787, 121494.67, 8)
# ('Goiás', 700, 142389.09, 9)
# ('Goiás', 3358, 136881.19, 7)
# ('Goiás', 2850, 107155.5, 5)
# ('Goiás', 1878, 96862.1, 4)
# ('Maranhão', 2811, 184101.89, 13)
# ('Maranhão', 441, 14945.13, 8)
# ('Maranhão', 191, 26216.35, 7)
# ('Mato Grosso', 2340, 165197.3, 9)
# ('Mato Grosso', 1192, 16001.5, 7)
# ('Mato Grosso do Sul', 679, 152271.96, 6)
# ('Mato Grosso do Sul', 2492, 17998.0, 3)
# ('Minas Gerais', 3090, 95697.3, 9)
# ('Minas Gerais', 2438, 95031.67, 8)
# ('Minas Gerais', 2216, 85841.41, 7)
# ('Minas Gerais', 796, 28161.0, 7)
# ('Minas Gerais', 2009, 24173.87, 6)
# ('Paraná', 2843, 137228.01, 10)
# ('Paraná', 2597, 55295.79, 6)
# ('Paraná', 2392, 41412.09, 6)
# ('Paraná', 898, 15390.8, 5)
# ('Paraíba', 464, 73556.1, 6)
# ('Paraíba', 1796, 54689.7, 3)
# ('Pernambuco', 2669, 37119.0, 7)
# ('Pernambuco', 2646, 135556.7, 7)
# ('Piauí', 2441, 40866.19, 5)
# ('Piauí', 1974, 139997.47, 5)
# ('Rio Grande do Norte', 3403, 136347.01, 10)
# ('Rio Grande do Norte', 2034, 221747.56, 6)
# ('Rio Grande do Norte', 185, 1327.1, 2)
# ('Rio Grande do Sul', 28, 29114.45, 9)
# ('Rio Grande do Sul', 1415, 3015.63, 7)
# ('Rio Grande do Sul', 2350, 31833.23, 6)
# ('Rio Grande do Sul', 1696, 1517.27, 6)
# ('Rio Grande do Sul', 89, 92027.37, 6)
# ('Santa Catarina', 2551, 187513.66, 9)
# ('Santa Catarina', 1074, 159165.18, 9)
# ('Santa Catarina', 2183, 8069.51, 6)
# ('Santa Catarina', 999, 28262.19, 6)
# ('Santa Catarina', 813, 100266.92, 5)
# ('São Paulo', 1756, 134413.0, 8)
# ('São Paulo', 3040, 54400.24, 7)
# ('São Paulo', 2920, 75686.31, 6)
# ('São Paulo', 1769, 88511.45, 6)
# ('São Paulo', 1691, 51763.32, 6)
# ('Tocantins', 1752, 97028.45, 8)
# ('Tocantins', 156, 12910.47, 3)

# %% [markdown]
# # PERGUNTA 4:
#
# ### Escreva um comando em SQL que retorne quais são os 3 produtos mais comprados dos estados da região Sul e Sudeste, a quantidade de itens comprados, o valor total pago e a média de preço paga

# %%
query = '''
   SELECT estado,
          cod_produto,
          qtd_itens,
          sum_compras,
          avg_compras
     FROM (
      SELECT u.estado,
            p.cod_produto, 
            count(1) qtd_itens,
            ROUND(SUM(valor),2) sum_compras,
            ROUND(AVG(valor),2) avg_compras,
            row_number() over (partition by u.estado order by count(1) DESC) as rank
        FROM vendas v
        JOIN usuarios u
          ON u.cod_usuario = v.cod_usuario
        JOIN produtos p
          ON p.cod_produto = v.cod_produto
        WHERE u.estado in ("Paraná", "Santa Catarina", "Rio Grande do Sul",
                           "Espírito Santo", "Minas Gerais", "Rio de Janeiro","São Paulo")
      GROUP BY p.cod_produto
     ) AS rank
   WHERE rank <= 3
'''

with execute_query(query) as rows:
    for row in rows:
        print(row)
# Out:
# ('Minas Gerais', 15, 26, 1397.2, 53.74)
# ('Minas Gerais', 1, 14, 615180.6, 43941.47)
# ('Minas Gerais', 5, 13, 61617.0, 4739.77)
# ('Paraná', 2, 6, 95550.38, 15925.06)
# ('Rio Grande do Sul', 7, 3, 67625.48, 22541.83)
# ('São Paulo', 17, 14, 56073.6, 4005.26)
# ('São Paulo', 10, 11, 81188.4, 7380.76)
# ('São Paulo', 16, 8, 270.0, 33.75)

# %% [markdown]
# # PERGUNTA 5:
#
# ### Escreva um comando em SQL que retorne o ticket médio e o número total de usuários que fizeram pelo menos uma compra por faixa etária

# %%
query = '''
    SELECT u.faixa_etaria,
           ROUND(AVG(v.valor),2) tkt_medio,
           COUNT(1) qtd_usuarios,
      FROM vendas v
      JOIN usuarios u
        ON u.cod_usuario = v.cod_usuario
    GROUP BY u.faixa_etaria
'''

with execute_query(query) as rows:
    for row in rows:
        print(row)
# Out:
# ('Entre 10 a 15 anos', 8890.13, 43)
# ('Entre 16 a 21 anos', 12725.95, 50)
# ('Entre 22 a 27 anos', 12203.02, 64)
# ('Entre 28 a 36 anos', 8233.04, 56)
# ('Entre 37 a 49 anos', 16727.19, 42)
# ('Entre 50 a 61 anos', 10849.48, 80)
# ('Entre 62 a 70 anos', 10012.63, 39)
# ('Mais de 70 anos', 11303.1, 29)

# %% [markdown]
# # PERGUNTA 6:
#
# ### Escreva um comando em SQL que aplique um desconto de 10% em todas as vendas dos usuários que fizeram pelo menos 3 compras de produtos na mesma categoria, a partir da 4ª compra realizada. Exiba apenas os usuários que terão o desconto aplicado, mantendo todas as compras, o valor original e o valor com o desconto aplicado

# %%
query = '''
    SELECT cod_usuario,
        cod_produto,
        valor,
        ROUND((valor - (valor * 0.10)), 2) valor_com_desc
    FROM (
        SELECT u.cod_usuario,
            v.cod_produto,
            v.valor,
            row_number() over (partition by u.cod_usuario, p.categoria_produto) as rank  
        FROM vendas v
        JOIN usuarios u
            ON u.cod_usuario = v.cod_usuario
        JOIN produtos p
          ON p.cod_produto = v.cod_produto
        ) as q
    WHERE rank > 3
'''

with execute_query(query) as rows:
    for row in rows:
        print(row)
# Out:
# (2438, 15, 39.92, 35.93)
# (2811, 1, 36727.2, 33054.48)
# (2811, 1, 18363.6, 16527.24)

# %% [markdown]
# # PERGUNTA 7
#
# ### Escreva um comando em SQL que retorna o produto, quantos usuários fizeram pelo menos uma compra desse produto e qual é o valor mínimo e máximo pago

# %%
query = '''
    SELECT v.cod_produto,
           count(1) qtd_usuario,
           min(v.valor) min_valor,
           max(v.valor) max_valor
      FROM vendas v
      JOIN usuarios u
        ON u.cod_usuario = v.cod_usuario
    GROUP BY
      v.cod_produto
'''

with execute_query(query) as rows:
    for row in rows:
        print(row)
# Out:
# (1, 29, 4590.9, 82636.2)
# (2, 15, 2691.56, 26915.6)
# (3, 12, 4099.0, 40990.0)
# (4, 12, 58.9, 1178.0)
# (5, 27, 874.0, 8740.0)
# (6, 21, 899.9, 17098.1)
# (7, 13, 1300.49, 24709.31)
# (8, 21, 219.57, 3732.69)
# (9, 13, 389.1, 6614.7)
# (10, 19, 2099.7, 13298.1)
# (11, 18, 49.9, 848.3)
# (12, 21, 77.5, 1550.0)
# (13, 16, 29.7, 198.0)
# (14, 18, 138.99, 2779.8)
# (15, 36, 4.99, 99.8)
# (16, 18, 5.0, 100.0)
# (17, 28, 584.1, 11097.9)
# (18, 13, 7.9, 158.0)
# (19, 13, 2499.9, 42498.3)
# (20, 13, 129.9, 2598.0)
# (21, 27, 5999.1, 119982.0)

# %% [markdown]
# # PERGUNTA 8
#
# ### Escreva um comando em SQL que retorne o total de compras realizadas, o total de itens comprados e a receita total obtida

# %%
query = '''
    SELECT count(1) tot_compras,
           ROUND(sum(quantidade),2) sum_items_vendidos,
           ROUND(sum(valor),2) tot_receita
      FROM vendas
'''

with execute_query(query) as rows:
    for row in rows:
        print(row)
# Out:
# (20000, 209149.0, 215849001.66)

# %% [markdown]
# # PERGUNTA 9
#
# ### Escreva um comando em SQL que retorne o produto, a quantidade de itens vendidos e a receita do produto que tem mais itens vendidos por ano e mês

# %%
query = '''
  SELECT ano_mes,
         cod_produto,
         sum_itens_vendidos,
         tot_receita
    FROM (
      SELECT strftime('%Y-%m', data_compra) ano_mes,
            cod_produto,
            sum(quantidade) sum_itens_vendidos,
            ROUND(sum(valor),2) tot_receita,
            row_number() over (partition by strftime('%Y-%m', data_compra) order by sum(quantidade) DESC) as rank
        FROM vendas
      GROUP BY
        strftime('%Y-%m', data_compra),
        cod_produto
      ) AS Q
    WHERE rank = 1
'''

with execute_query(query) as rows:
    for row in rows:
        print(row)
# Out:
# ('2018-01', 3, 17, 34841.5)
# ('2018-02', 11, 35, 1746.5)
# ('2018-03', 16, 38, 190.0)
# ('2018-04', 3, 50, 102475.0)
# ('2018-05', 5, 43, 18791.0)
# ('2018-06', 12, 47, 3642.5)
# ('2018-07', 10, 62, 43393.8)
# ('2018-08', 2, 89, 119774.42)
# ('2018-09', 7, 87, 113142.63)
# ('2018-10', 17, 99, 57825.9)
# ('2018-11', 1, 85, 390226.5)
# ('2018-12', 18, 102, 805.8)
# ('2019-01', 21, 135, 809878.5)
# ('2019-02', 9, 82, 31906.2)
# ('2019-03', 4, 142, 8363.8)
# ('2019-04', 15, 167, 833.33)
# ('2019-05', 2, 164, 220707.92)
# ('2019-06', 11, 177, 8832.3)
# ('2019-07', 19, 234, 584976.6)
# ('2019-08', 3, 273, 559513.5)
# ('2019-09', 1, 210, 964089.0)
# ('2019-10', 20, 222, 28837.8)
# ('2019-11', 5, 252, 110124.0)
# ('2019-12', 4, 321, 18906.9)
# ('2020-01', 8, 301, 66090.57)
# ('2020-02', 7, 282, 366738.18)
# ('2020-03', 11, 329, 16417.1)
# ('2020-04', 3, 343, 702978.5)
# ('2020-05', 7, 395, 513693.55)
# ('2020-06', 10, 416, 291158.4)
# ('2020-07', 16, 395, 1975.0)
# ('2020-08', 11, 461, 23003.9)
# ('2020-09', 6, 446, 401355.4)
# ('2020-10', 13, 482, 4771.8)
# ('2020-11', 9, 484, 188324.4)
# ('2020-12', 13, 490, 4851.0)
# ('2021-01', 10, 599, 419240.1)
# ('2021-02', 20, 589, 76511.1)
# ('2021-03', 4, 765, 45058.5)
# ('2021-04', 5, 731, 319447.0)
# ('2021-05', 7, 871, 1132726.79)
# ('2021-06', 20, 1212, 157438.8)
# ('2021-07', 21, 1628, 9766534.8)

# %% [markdown]
# # PERGUNTA 10
#
# ### Escreva um comando em SQL que exiba quem são os usuários que compraram produtos diferentes

# %%
# irei considerar que os produtos distintos foram comprados
# na mesma data (possivelmente mesma compra?)
query = '''
    SELECT DISTINCT v1.cod_usuario
    FROM vendas v1
    JOIN vendas v2
      ON v1.cod_usuario = v2.cod_usuario
      AND v1.data_compra = v2.data_compra
      AND v1.cod_produto <> v2.cod_produto
'''

with execute_query(query) as rows:
    for row in rows:
        print(row)
# Out:
# (1919,)
# (3272,)
# (2514,)
# (314,)
# (3389,)
# (881,)
# (453,)
# (104,)
# (2,)
# (1091,)
# (1501,)
# (285,)
# (2722,)
# (107,)
# (3119,)
# (1118,)
# (2977,)
# (3160,)
# (2822,)
# (136,)
# (3408,)
# (2624,)
# (2260,)
# (840,)
# (1923,)
# (997,)
# (2349,)
# (2909,)
# (1491,)
# (3300,)
# (719,)
# (1139,)
# (642,)
# (1051,)
# (778,)
# (320,)
# (843,)
# (674,)
# (53,)
# (395,)
# (979,)
# (2573,)
# (2416,)
# (898,)
# (761,)
# (1210,)
# (2223,)
# (1449,)
# (132,)
# (31,)
# (1495,)
# (2469,)
# (1251,)
# (437,)
# (2013,)
# (17,)
# (1398,)
# (119,)
# (1525,)
# (1310,)
# (1691,)
# (1967,)
# (3109,)
# (2778,)
# (2950,)
# (1023,)
# (3156,)
# (2975,)
# (1330,)
# (277,)
# (1178,)
# (1855,)
# (684,)
# (431,)
# (1911,)
# (211,)
# (1942,)
# (3317,)
# (2355,)
# (1781,)
# (2805,)
# (189,)
# (2356,)
# (2627,)
# (788,)
# (421,)
# (50,)
# (2188,)
# (1022,)
# (1766,)
# (516,)
# (309,)
# (452,)
# (1058,)
# (2640,)
# (2633,)
# (1106,)
# (2197,)
# (621,)
# (1422,)
# (1142,)
# (411,)
# (2396,)
# (2581,)
# (2400,)
# (333,)
# (71,)
# (404,)
# (3333,)
# (968,)
# (1298,)
# (2999,)
# (1917,)
# (8,)
# (533,)
# (2199,)
# (2130,)
# (1521,)
# (2985,)
# (15,)
# (2852,)
# (1465,)
# (635,)
# (928,)
# (1936,)
# (1131,)
# (2745,)
# (68,)
# (3339,)
# (3,)
# (715,)
# (1924,)
# (2027,)
# (2138,)
# (3088,)
# (195,)
# (2056,)
# (593,)
# (393,)
# (1912,)
# (738,)
# (261,)
# (2151,)
# (1214,)
# (1009,)
# (892,)
# (1846,)
# (249,)
# (2986,)
# (184,)
# (3206,)
# (1100,)
# (2431,)
# (2385,)
# (940,)
# (3059,)
# (3203,)
# (78,)
# (1724,)
# (1470,)
# (2202,)
# (1034,)
# (2047,)
# (1791,)
# (878,)
# (1680,)
# (1463,)
# (1754,)
# (1632,)
# (3139,)
# (2516,)
# (2419,)
# (1675,)
# (1372,)
# (2458,)
# (887,)
# (3095,)
# (1203,)
# (146,)
# (1232,)
# (1383,)
# (482,)
# (1854,)
# (499,)
# (115,)
# (2599,)
# (251,)
# (598,)
# (1972,)
# (2608,)
# (2208,)
# (3278,)
# (759,)
# (2040,)
# (3212,)
# (2740,)
# (1326,)
# (408,)
# (589,)
# (92,)
# (943,)
# (1208,)
# (1427,)
# (770,)
# (1769,)
# (1477,)
# (3022,)
# (767,)
# (22,)
# (617,)
# (3290,)
# (1736,)
# (3336,)
# (2906,)
# (1508,)
# (12,)
# (337,)
# (2922,)
# (726,)
# (1054,)

# %% [markdown]
# # PERGUNTA 11
#
# ### Escreva um comando em SQL que verifique usuários que não fizeram nenhuma compra

# %%
query = '''
    SELECT u.cod_usuario
    FROM usuarios u
    LEFT JOIN vendas v
      ON v.cod_usuario = u.cod_usuario
    WHERE v.cod_usuario IS NULL
      AND u.cod_usuario <> ''
'''

with execute_query(query) as rows:
    for row in rows:
        print(row)
# Out:
# ('cod_usuario', 'cod_usuario', 'data_cadastro', 'faixa_etaria', 'cidade', 'estado', None, None, None, None, None)
# (5098, 5098, '2021-05-03', 'Entre 62 a 70 anos', 'Guaraci', 'Paraná', None, None, None, None, None)
# (5229, 5229, '2019-11-22', 'Entre 10 a 15 anos', 'Cerqueira César', 'São Paulo', None, None, None, None, None)
# (5482, 5482, '2020-09-22', 'Entre 62 a 70 anos', 'Bebedouro', 'São Paulo', None, None, None, None, None)
# (5504, 5504, '2019-09-01', 'Entre 16 a 21 anos', 'Cariri do Tocantins', 'Tocantins', None, None, None, None, None)
# (5614, 5614, '2020-11-02', 'Entre 50 a 61 anos', 'Itaguaçu da Bahia', 'Bahia', None, None, None, None, None)
# (5923, 5923, '2019-09-12', 'Entre 16 a 21 anos', 'Coremas', 'Paraíba', None, None, None, None, None)
# (6985, 6985, '2019-09-12', 'Entre 62 a 70 anos', 'Brejetuba', 'Espírito Santo', None, None, None, None, None)
# (7901, 7901, '2019-09-28', 'Entre 16 a 21 anos', 'Itaguaí', 'Rio de Janeiro', None, None, None, None, None)
# (9980, 9980, '2021-02-09', 'Entre 62 a 70 anos', 'Sátiro Dias', 'Bahia', None, None, None, None, None)
# (10080, 10080, '2020-09-21', 'Entre 10 a 15 anos', 'Rio Sono', 'Tocantins', None, None, None, None, None)
# (10152, 10152, '2019-10-29', 'Entre 62 a 70 anos', 'General Carneiro', 'Mato Grosso', None, None, None, None, None)
# (10170, 10170, '2020-09-18', 'Entre 16 a 21 anos', 'Juazeiro', 'Bahia', None, None, None, None, None)
# (10929, 10929, '2021-04-10', 'Entre 37 a 49 anos', 'Brejo dos Santos', 'Paraíba', None, None, None, None, None)
# (11002, 11002, '2019-11-27', 'Entre 16 a 21 anos', 'Santo Antônio das Missões', 'Rio Grande do Sul', None, None, None, None, None)
# (11546, 11546, '2021-07-04', 'Entre 10 a 15 anos', 'Abreulândia', 'Tocantins', None, None, None, None, None)
# (12298, 12298, '2020-04-13', 'Entre 28 a 36 anos', 'Nazário', 'Goiás', None, None, None, None, None)
# (12354, 12354, '2019-07-02', 'Entre 50 a 61 anos', 'Saudades', 'Santa Catarina', None, None, None, None, None)
# (13117, 13117, '2019-11-13', 'Mais de 70 anos', 'Jari', 'Rio Grande do Sul', None, None, None, None, None)
# (13476, 13476, '2021-06-28', 'Entre 28 a 36 anos', 'Campina Verde', 'Minas Gerais', None, None, None, None, None)
# (14486, 14486, '2020-08-12', 'Entre 22 a 27 anos', 'Coxixola', 'Paraíba', None, None, None, None, None)
# (15198, 15198, '2020-04-03', 'Mais de 70 anos', 'Urubici', 'Santa Catarina', None, None, None, None, None)
# (15313, 15313, '2019-11-18', 'Entre 50 a 61 anos', 'Tabaí', 'Rio Grande do Sul', None, None, None, None, None)
# (15784, 15784, '2019-09-16', 'Entre 37 a 49 anos', 'São Vicente do Seridó', 'Paraíba', None, None, None, None, None)
# (16570, 16570, '2020-09-03', 'Entre 22 a 27 anos', 'Cachoeirinha', 'Pernambuco', None, None, None, None, None)
# (17530, 17530, '2019-09-26', 'Entre 28 a 36 anos', 'Mato Queimado', 'Rio Grande do Sul', None, None, None, None, None)
# (17779, 17779, '2021-05-22', 'Entre 28 a 36 anos', 'Matinhas', 'Paraíba', None, None, None, None, None)
# (18028, 18028, '2020-09-29', 'Mais de 70 anos', 'Lacerdópolis', 'Santa Catarina', None, None, None, None, None)
# (18034, 18034, '2019-05-04', 'Entre 22 a 27 anos', 'São Luís', 'Maranhão', None, None, None, None, None)
# (18166, 18166, '2019-12-27', 'Entre 62 a 70 anos', 'Rancho Alegre', 'Paraná', None, None, None, None, None)
# (18366, 18366, '2019-09-08', 'Entre 28 a 36 anos', 'Cachoeira Paulista', 'São Paulo', None, None, None, None, None)
# (19078, 19078, '2021-05-03', 'Entre 37 a 49 anos', 'Angelândia', 'Minas Gerais', None, None, None, None, None)
# (19231, 19231, '2019-08-21', 'Entre 16 a 21 anos', 'Salto da Divisa', 'Minas Gerais', None, None, None, None, None)
# (19445, 19445, '2020-03-07', 'Entre 22 a 27 anos', 'Congonhal', 'Minas Gerais', None, None, None, None, None)
# (19590, 19590, '2021-06-26', 'Entre 16 a 21 anos', 'Eldorado', 'São Paulo', None, None, None, None, None)
# (19798, 19798, '2019-04-05', 'Entre 22 a 27 anos', 'Cordisburgo', 'Minas Gerais', None, None, None, None, None)
# (19984, 19984, '2019-01-14', 'Mais de 70 anos', 'Duque de Caxias', 'Rio de Janeiro', None, None, None, None, None)
# (20067, 20067, '2021-07-23', 'Entre 37 a 49 anos', 'Dom Expedito Lopes', 'Piauí', None, None, None, None, None)
# (20207, 20207, '2020-04-08', 'Entre 22 a 27 anos', 'Conceição do Almeida', 'Bahia', None, None, None, None, None)
# (20425, 20425, '2020-02-01', 'Entre 62 a 70 anos', 'Sarzedo', 'Minas Gerais', None, None, None, None, None)
# (21347, 21347, '2019-05-30', 'Entre 50 a 61 anos', 'Jangada', 'Mato Grosso', None, None, None, None, None)
# (21440, 21440, '2021-05-13', 'Entre 28 a 36 anos', 'Ibititá', 'Bahia', None, None, None, None, None)
# (21481, 21481, '2020-06-12', 'Entre 28 a 36 anos', 'Bariri', 'São Paulo', None, None, None, None, None)
# (22113, 22113, '2019-01-28', 'Entre 16 a 21 anos', 'São Jorge do Ivaí', 'Paraná', None, None, None, None, None)
# (22188, 22188, '2019-03-15', 'Entre 10 a 15 anos', 'Frei Inocêncio', 'Minas Gerais', None, None, None, None, None)
# (22290, 22290, '2020-12-21', 'Mais de 70 anos', 'Brasília de Minas', 'Minas Gerais', None, None, None, None, None)
# (22321, 22321, '2020-07-19', 'Entre 28 a 36 anos', 'Júlio Borges', 'Piauí', None, None, None, None, None)
# (22470, 22470, '2020-10-16', 'Entre 22 a 27 anos', 'Tijucas do Sul', 'Paraná', None, None, None, None, None)
# (22692, 22692, '2021-04-10', 'Entre 10 a 15 anos', 'Eusébio', 'Ceará', None, None, None, None, None)
# (23077, 23077, '2021-06-28', 'Entre 28 a 36 anos', 'Chapadão do Lageado', 'Santa Catarina', None, None, None, None, None)
# (23127, 23127, '2020-06-12', 'Entre 10 a 15 anos', 'Pentecoste', 'Ceará', None, None, None, None, None)
# (23618, 23618, '2019-05-12', 'Entre 28 a 36 anos', 'Itanhaém', 'São Paulo', None, None, None, None, None)
# (23732, 23732, '2021-06-18', 'Entre 37 a 49 anos', 'Echaporã', 'São Paulo', None, None, None, None, None)
# (23858, 23858, '2019-06-21', 'Entre 22 a 27 anos', 'Bonito de Minas', 'Minas Gerais', None, None, None, None, None)
# (24216, 24216, '2020-09-04', 'Entre 62 a 70 anos', 'Timbaúba dos Batistas', 'Rio Grande do Norte', None, None, None, None, None)
# (24470, 24470, '2020-05-03', 'Entre 16 a 21 anos', 'Ipixuna', 'Amazonas', None, None, None, None, None)
# (24951, 24951, '2019-06-20', 'Entre 62 a 70 anos', 'Joanésia', 'Minas Gerais', None, None, None, None, None)
# (25517, 25517, '2020-07-30', 'Entre 28 a 36 anos', 'Girau do Ponciano', 'Alagoas', None, None, None, None, None)
# (25638, 25638, '2020-03-11', 'Entre 10 a 15 anos', 'Coqueiral', 'Minas Gerais', None, None, None, None, None)
# (25923, 25923, '2020-04-13', 'Entre 22 a 27 anos', 'Óbidos', 'Pará', None, None, None, None, None)
# (26156, 26156, '2020-02-27', 'Entre 28 a 36 anos', 'Eugenópolis', 'Minas Gerais', None, None, None, None, None)
# (26514, 26514, '2021-06-15', 'Entre 22 a 27 anos', 'Assis', 'São Paulo', None, None, None, None, None)
# (27003, 27003, '2020-04-24', 'Entre 50 a 61 anos', 'Balneário Rincão', 'Santa Catarina', None, None, None, None, None)
# (27222, 27222, '2020-12-26', 'Entre 22 a 27 anos', 'São Pedro da União', 'Minas Gerais', None, None, None, None, None)
# (27417, 27417, '2019-10-06', 'Entre 16 a 21 anos', 'Cipotânea', 'Minas Gerais', None, None, None, None, None)
# (27642, 27642, '2019-08-08', 'Entre 37 a 49 anos', 'Itutinga', 'Minas Gerais', None, None, None, None, None)
# (27859, 27859, '2021-02-22', 'Entre 16 a 21 anos', 'Iracema do Oeste', 'Paraná', None, None, None, None, None)
# (27870, 27870, '2019-03-27', 'Entre 22 a 27 anos', 'Fundão', 'Espírito Santo', None, None, None, None, None)
# (28538, 28538, '2019-12-25', 'Entre 10 a 15 anos', 'Paiva', 'Minas Gerais', None, None, None, None, None)
# (28877, 28877, '2019-03-21', 'Entre 50 a 61 anos', 'Braganey', 'Paraná', None, None, None, None, None)
# (29003, 29003, '2019-11-29', 'Entre 28 a 36 anos', 'Capitão Enéas', 'Minas Gerais', None, None, None, None, None)
# (29581, 29581, '2020-09-26', 'Mais de 70 anos', 'Espírito Santo do Dourado', 'Minas Gerais', None, None, None, None, None)
# (29611, 29611, '2020-07-26', 'Entre 62 a 70 anos', 'Ivaí', 'Paraná', None, None, None, None, None)
# (30117, 30117, '2020-03-06', 'Entre 28 a 36 anos', 'Canoas', 'Rio Grande do Sul', None, None, None, None, None)
# (30362, 30362, '2020-06-10', 'Entre 10 a 15 anos', 'Sapé', 'Paraíba', None, None, None, None, None)
# (30697, 30697, '2020-07-25', 'Mais de 70 anos', 'Passo do Sobrado', 'Rio Grande do Sul', None, None, None, None, None)
# (31115, 31115, '2021-06-05', 'Entre 37 a 49 anos', 'Potiretama', 'Ceará', None, None, None, None, None)
# (31286, 31286, '2021-01-13', 'Entre 62 a 70 anos', 'Magda', 'São Paulo', None, None, None, None, None)
# (31765, 31765, '2019-03-16', 'Mais de 70 anos', 'São Bernardo', 'Maranhão', None, None, None, None, None)
# (32872, 32872, '2020-10-05', 'Entre 28 a 36 anos', 'Imaculada', 'Paraíba', None, None, None, None, None)
# (32932, 32932, '2019-02-04', 'Entre 28 a 36 anos', 'Faxinal', 'Paraná', None, None, None, None, None)
# (33574, 33574, '2020-05-19', 'Entre 22 a 27 anos', 'Itaquaquecetuba', 'São Paulo', None, None, None, None, None)
# (33661, 33661, '2020-04-29', 'Entre 22 a 27 anos', 'Ipiranga do Piauí', 'Piauí', None, None, None, None, None)
# (33684, 33684, '2020-06-21', 'Entre 50 a 61 anos', 'Santa Maria do Oeste', 'Paraná', None, None, None, None, None)
# (33869, 33869, '2021-03-15', 'Entre 37 a 49 anos', 'São Sebastião do Rio Preto', 'Minas Gerais', None, None, None, None, None)
# (34126, 34126, '2020-11-11', 'Entre 16 a 21 anos', 'Águas de Santa Bárbara', 'São Paulo', None, None, None, None, None)
# (34180, 34180, '2020-04-26', 'Entre 62 a 70 anos', 'Alfredo Marcondes', 'São Paulo', None, None, None, None, None)
# (34232, 34232, '2019-05-24', 'Entre 50 a 61 anos', 'Coronel Murta', 'Minas Gerais', None, None, None, None, None)
# (34324, 34324, '2021-07-28', 'Entre 10 a 15 anos', 'Corumbá', 'Mato Grosso do Sul', None, None, None, None, None)
# (35041, 35041, '2020-12-21', 'Mais de 70 anos', 'Cristiano Otoni', 'Minas Gerais', None, None, None, None, None)
# (35167, 35167, '2019-01-31', 'Mais de 70 anos', 'São Pedro da União', 'Minas Gerais', None, None, None, None, None)
# (35524, 35524, '2021-01-11', 'Entre 50 a 61 anos', 'Tanabi', 'São Paulo', None, None, None, None, None)
# (35656, 35656, '2021-06-11', 'Entre 16 a 21 anos', 'Prado Ferreira', 'Paraná', None, None, None, None, None)
# (35700, 35700, '2021-06-22', 'Entre 50 a 61 anos', 'Ubaitaba', 'Bahia', None, None, None, None, None)
# (35855, 35855, '2019-11-02', 'Entre 37 a 49 anos', 'Lagoa de Velhos', 'Rio Grande do Norte', None, None, None, None, None)
# (36314, 36314, '2021-04-14', 'Entre 22 a 27 anos', 'Esmeralda', 'Rio Grande do Sul', None, None, None, None, None)
# (36354, 36354, '2020-05-25', 'Mais de 70 anos', 'Pajeú do Piauí', 'Piauí', None, None, None, None, None)
# (36548, 36548, '2019-03-03', 'Entre 10 a 15 anos', 'Nova Resende', 'Minas Gerais', None, None, None, None, None)
# (36738, 36738, '2020-04-21', 'Entre 28 a 36 anos', 'Jacareí', 'São Paulo', None, None, None, None, None)
# (36742, 36742, '2021-01-17', 'Entre 50 a 61 anos', 'Novo Horizonte do Norte', 'Mato Grosso', None, None, None, None, None)
# (36935, 36935, '2021-05-25', 'Entre 28 a 36 anos', 'Brejões', 'Bahia', None, None, None, None, None)
# (37127, 37127, '2019-07-31', 'Entre 37 a 49 anos', 'Itarantim', 'Bahia', None, None, None, None, None)
# (37331, 37331, '2019-07-17', 'Entre 22 a 27 anos', 'Parobé', 'Rio Grande do Sul', None, None, None, None, None)
# (38002, 38002, '2021-07-21', 'Entre 62 a 70 anos', 'Araranguá', 'Santa Catarina', None, None, None, None, None)
# (38248, 38248, '2021-07-03', 'Entre 16 a 21 anos', 'Rio do Prado', 'Minas Gerais', None, None, None, None, None)
# (38779, 38779, '2019-02-27', 'Entre 16 a 21 anos', 'Cidelândia', 'Maranhão', None, None, None, None, None)
# (38819, 38819, '2020-10-12', 'Entre 22 a 27 anos', 'Alto Piquiri', 'Paraná', None, None, None, None, None)
# (39239, 39239, '2020-10-23', 'Entre 16 a 21 anos', 'Passa Quatro', 'Minas Gerais', None, None, None, None, None)
# (39388, 39388, '2020-09-20', 'Entre 62 a 70 anos', 'Lauro de Freitas', 'Bahia', None, None, None, None, None)
# (39635, 39635, '2019-11-30', 'Entre 62 a 70 anos', "Mirassol d'Oeste", 'Mato Grosso', None, None, None, None, None)
# (40009, 40009, '2020-07-27', 'Entre 16 a 21 anos', 'Teutônia', 'Rio Grande do Sul', None, None, None, None, None)
# (40109, 40109, '2021-01-14', 'Mais de 70 anos', 'São Gabriel do Oeste', 'Mato Grosso do Sul', None, None, None, None, None)
# (40147, 40147, '2019-10-11', 'Entre 50 a 61 anos', 'Jacutinga', 'Minas Gerais', None, None, None, None, None)
# (40173, 40173, '2019-04-12', 'Entre 28 a 36 anos', 'Chã de Alegria', 'Pernambuco', None, None, None, None, None)
# (40378, 40378, '2020-10-11', 'Entre 22 a 27 anos', 'Nova Canaã do Norte', 'Mato Grosso', None, None, None, None, None)
# (40410, 40410, '2021-02-27', 'Entre 28 a 36 anos', 'Jupi', 'Pernambuco', None, None, None, None, None)
# (41033, 41033, '2019-12-28', 'Entre 16 a 21 anos', 'Afonso Cunha', 'Maranhão', None, None, None, None, None)
# (41037, 41037, '2020-02-08', 'Entre 22 a 27 anos', 'Borborema', 'São Paulo', None, None, None, None, None)
# (41337, 41337, '2019-05-19', 'Entre 37 a 49 anos', 'Sabáudia', 'Paraná', None, None, None, None, None)
# (41409, 41409, '2021-05-30', 'Entre 28 a 36 anos', 'Carnaubeira da Penha', 'Pernambuco', None, None, None, None, None)
# (41835, 41835, '2020-10-11', 'Entre 50 a 61 anos', 'Maxaranguape', 'Rio Grande do Norte', None, None, None, None, None)
# (42252, 42252, '2019-03-03', 'Entre 16 a 21 anos', 'Itaguaçu da Bahia', 'Bahia', None, None, None, None, None)
# (42918, 42918, '2020-07-06', 'Entre 50 a 61 anos', 'Taquaraçu de Minas', 'Minas Gerais', None, None, None, None, None)
# (43018, 43018, '2019-01-10', 'Mais de 70 anos', 'Bonito', 'Bahia', None, None, None, None, None)
# (43211, 43211, '2020-01-02', 'Entre 50 a 61 anos', 'Ibicuí', 'Bahia', None, None, None, None, None)
# (44180, 44180, '2019-02-25', 'Entre 62 a 70 anos', 'Antônio Prado', 'Rio Grande do Sul', None, None, None, None, None)
# (44271, 44271, '2020-03-02', 'Entre 62 a 70 anos', 'Ubaporanga', 'Minas Gerais', None, None, None, None, None)
# (44283, 44283, '2021-02-03', 'Entre 50 a 61 anos', 'Benevides', 'Pará', None, None, None, None, None)
# (44311, 44311, '2020-05-17', 'Entre 37 a 49 anos', 'Pedra Preta', 'Mato Grosso', None, None, None, None, None)
# (44911, 44911, '2019-08-03', 'Entre 22 a 27 anos', 'Major Vieira', 'Santa Catarina', None, None, None, None, None)
# (45205, 45205, '2021-03-09', 'Entre 62 a 70 anos', 'Inhangapi', 'Pará', None, None, None, None, None)
# (45393, 45393, '2021-01-19', 'Entre 16 a 21 anos', 'Amarante do Maranhão', 'Maranhão', None, None, None, None, None)
# (46826, 46826, '2019-04-09', 'Entre 16 a 21 anos', 'Sananduva', 'Rio Grande do Sul', None, None, None, None, None)
# (46988, 46988, '2020-09-04', 'Entre 28 a 36 anos', 'São Miguel de Taipu', 'Paraíba', None, None, None, None, None)
# (47355, 47355, '2020-11-23', 'Entre 22 a 27 anos', 'Estrela', 'Rio Grande do Sul', None, None, None, None, None)
# (47514, 47514, '2020-12-17', 'Entre 37 a 49 anos', 'Chiador', 'Minas Gerais', None, None, None, None, None)
# (47909, 47909, '2019-07-23', 'Entre 16 a 21 anos', 'Canoas', 'Rio Grande do Sul', None, None, None, None, None)
# (47983, 47983, '2019-06-23', 'Mais de 70 anos', 'Tupanciretã', 'Rio Grande do Sul', None, None, None, None, None)
# (48286, 48286, '2019-12-13', 'Entre 22 a 27 anos', 'Congonhinhas', 'Paraná', None, None, None, None, None)
# (48449, 48449, '2020-04-19', 'Entre 28 a 36 anos', 'Itapetim', 'Pernambuco', None, None, None, None, None)
# (48943, 48943, '2020-02-22', 'Entre 50 a 61 anos', 'Araporã', 'Minas Gerais', None, None, None, None, None)
# (49534, 49534, '2019-07-25', 'Entre 28 a 36 anos', 'Dois Irmãos do Buriti', 'Mato Grosso do Sul', None, None, None, None, None)
# (49670, 49670, '2020-03-14', 'Entre 37 a 49 anos', 'Sagrada Família', 'Rio Grande do Sul', None, None, None, None, None)
# (50207, 50207, '2020-01-28', 'Entre 37 a 49 anos', 'Mirante da Serra', 'Rondônia', None, None, None, None, None)
# (50732, 50732, '2021-04-18', 'Mais de 70 anos', 'Santaluz', 'Bahia', None, None, None, None, None)
# (50939, 50939, '2019-09-13', 'Mais de 70 anos', 'Francisco Macedo', 'Piauí', None, None, None, None, None)
# (51510, 51510, '2020-01-03', 'Entre 50 a 61 anos', 'São José do Belmonte', 'Pernambuco', None, None, None, None, None)
# (51594, 51594, '2019-05-05', 'Entre 62 a 70 anos', 'Chapadão do Lageado', 'Santa Catarina', None, None, None, None, None)
# (51941, 51941, '2019-09-02', 'Entre 62 a 70 anos', 'Honório Serpa', 'Paraná', None, None, None, None, None)
# (52633, 52633, '2019-11-20', 'Entre 10 a 15 anos', 'Faina', 'Goiás', None, None, None, None, None)
# (52714, 52714, '2021-04-24', 'Entre 28 a 36 anos', 'Itaporanga', 'São Paulo', None, None, None, None, None)
# (52763, 52763, '2019-07-13', 'Entre 62 a 70 anos', 'Nantes', 'São Paulo', None, None, None, None, None)
# (53204, 53204, '2019-12-06', 'Mais de 70 anos', 'Lambari', 'Minas Gerais', None, None, None, None, None)
# (55092, 55092, '2021-01-07', 'Entre 62 a 70 anos', 'Arroio do Padre', 'Rio Grande do Sul', None, None, None, None, None)
# (55540, 55540, '2020-11-01', 'Entre 10 a 15 anos', 'São Raimundo das Mangabeiras', 'Maranhão', None, None, None, None, None)
# (55573, 55573, '2020-02-28', 'Entre 22 a 27 anos', 'Horizonte', 'Ceará', None, None, None, None, None)
# (56480, 56480, '2021-03-30', 'Entre 28 a 36 anos', 'Boa Vista do Buricá', 'Rio Grande do Sul', None, None, None, None, None)
# (56701, 56701, '2020-09-14', 'Mais de 70 anos', 'Tombos', 'Minas Gerais', None, None, None, None, None)
# (56705, 56705, '2021-02-13', 'Entre 16 a 21 anos', 'Lauro Müller', 'Santa Catarina', None, None, None, None, None)
# (57564, 57564, '2019-07-02', 'Entre 28 a 36 anos', 'Sobradinho', 'Rio Grande do Sul', None, None, None, None, None)
# (57674, 57674, '2019-11-03', 'Mais de 70 anos', 'Teresópolis', 'Rio de Janeiro', None, None, None, None, None)
# (57960, 57960, '2019-08-13', 'Entre 50 a 61 anos', 'União do Oeste', 'Santa Catarina', None, None, None, None, None)
# (58644, 58644, '2021-04-29', 'Entre 37 a 49 anos', 'Fagundes', 'Paraíba', None, None, None, None, None)
# (58655, 58655, '2020-09-28', 'Entre 28 a 36 anos', 'Oliveira de Fátima', 'Tocantins', None, None, None, None, None)
# (58659, 58659, '2019-01-07', 'Mais de 70 anos', 'Mercês', 'Minas Gerais', None, None, None, None, None)
# (58964, 58964, '2020-02-05', 'Mais de 70 anos', 'Paula Cândido', 'Minas Gerais', None, None, None, None, None)
# (58972, 58972, '2020-03-17', 'Mais de 70 anos', 'Guiricema', 'Minas Gerais', None, None, None, None, None)
# (59019, 59019, '2020-08-29', 'Entre 37 a 49 anos', 'Colíder', 'Mato Grosso', None, None, None, None, None)
# (59237, 59237, '2021-05-27', 'Entre 28 a 36 anos', 'Fortaleza de Minas', 'Minas Gerais', None, None, None, None, None)
# (59290, 59290, '2020-08-04', 'Entre 16 a 21 anos', 'Soledade de Minas', 'Minas Gerais', None, None, None, None, None)
# (60148, 60148, '2019-12-05', 'Entre 10 a 15 anos', 'Boqueirão do Piauí', 'Piauí', None, None, None, None, None)
# (60298, 60298, '2019-07-31', 'Entre 28 a 36 anos', 'Capão Bonito', 'São Paulo', None, None, None, None, None)
# (60944, 60944, '2020-03-20', 'Entre 10 a 15 anos', 'Santana de Mangueira', 'Paraíba', None, None, None, None, None)
# (61589, 61589, '2021-04-02', 'Entre 22 a 27 anos', 'Itumbiara', 'Goiás', None, None, None, None, None)
# (61662, 61662, '2020-07-15', 'Entre 28 a 36 anos', 'Avelino Lopes', 'Piauí', None, None, None, None, None)
# (61725, 61725, '2019-12-14', 'Entre 50 a 61 anos', 'Marzagão', 'Goiás', None, None, None, None, None)
# (62016, 62016, '2021-06-20', 'Entre 62 a 70 anos', 'Palmeiras', 'Bahia', None, None, None, None, None)
# (62584, 62584, '2019-12-06', 'Entre 50 a 61 anos', 'Bonfim', 'Minas Gerais', None, None, None, None, None)
# (62726, 62726, '2019-10-08', 'Entre 50 a 61 anos', 'Propriá', 'Sergipe', None, None, None, None, None)
# (63095, 63095, '2021-03-20', 'Entre 22 a 27 anos', 'Areia Branca', 'Rio Grande do Norte', None, None, None, None, None)
# (63371, 63371, '2020-06-21', 'Mais de 70 anos', 'Conceição do Araguaia', 'Pará', None, None, None, None, None)
# (63395, 63395, '2021-02-23', 'Entre 22 a 27 anos', 'Nazaré do Piauí', 'Piauí', None, None, None, None, None)
# (63523, 63523, '2020-09-05', 'Entre 28 a 36 anos', 'Matias Barbosa', 'Minas Gerais', None, None, None, None, None)
# (63640, 63640, '2020-03-07', 'Entre 22 a 27 anos', 'Pedras de Fogo', 'Paraíba', None, None, None, None, None)
# (64099, 64099, '2020-08-17', 'Entre 16 a 21 anos', 'Rio Novo do Sul', 'Espírito Santo', None, None, None, None, None)
# (64684, 64684, '2021-03-25', 'Entre 22 a 27 anos', 'Taiúva', 'São Paulo', None, None, None, None, None)
# (65417, 65417, '2020-06-25', 'Entre 50 a 61 anos', 'Erechim', 'Rio Grande do Sul', None, None, None, None, None)
# (65485, 65485, '2020-09-06', 'Mais de 70 anos', 'Buriti Bravo', 'Maranhão', None, None, None, None, None)
# (66240, 66240, '2019-08-20', 'Entre 37 a 49 anos', 'Guaranésia', 'Minas Gerais', None, None, None, None, None)
# (66626, 66626, '2021-04-03', 'Entre 50 a 61 anos', 'Itaguaçu', 'Espírito Santo', None, None, None, None, None)
# (66879, 66879, '2021-03-31', 'Entre 22 a 27 anos', 'Pedras Grandes', 'Santa Catarina', None, None, None, None, None)
# (67489, 67489, '2019-09-24', 'Entre 16 a 21 anos', 'São João da Varjota', 'Piauí', None, None, None, None, None)
# (67820, 67820, '2021-03-15', 'Entre 37 a 49 anos', 'Arapoema', 'Tocantins', None, None, None, None, None)
# (68090, 68090, '2019-02-19', 'Entre 28 a 36 anos', 'Louveira', 'São Paulo', None, None, None, None, None)
# (68322, 68322, '2019-04-30', 'Entre 22 a 27 anos', 'Itapaci', 'Goiás', None, None, None, None, None)
# (68559, 68559, '2021-07-12', 'Entre 22 a 27 anos', 'Terra Roxa', 'Paraná', None, None, None, None, None)
# (68677, 68677, '2019-04-18', 'Entre 16 a 21 anos', 'Baía Formosa', 'Rio Grande do Norte', None, None, None, None, None)
# (69054, 69054, '2021-01-12', 'Mais de 70 anos', "Conquista D'Oeste", 'Mato Grosso', None, None, None, None, None)
# (69184, 69184, '2019-08-10', 'Entre 22 a 27 anos', 'Mococa', 'São Paulo', None, None, None, None, None)
# (69399, 69399, '2020-05-09', 'Entre 50 a 61 anos', 'Muniz Freire', 'Espírito Santo', None, None, None, None, None)
# (69466, 69466, '2019-02-28', 'Entre 28 a 36 anos', 'Candelária', 'Rio Grande do Sul', None, None, None, None, None)
# (69692, 69692, '2019-06-18', 'Entre 10 a 15 anos', 'Mundo Novo', 'Bahia', None, None, None, None, None)
# (70156, 70156, '2020-08-29', 'Entre 37 a 49 anos', 'Camboriú', 'Santa Catarina', None, None, None, None, None)
# (70489, 70489, '2019-10-18', 'Entre 50 a 61 anos', 'Oliveira', 'Minas Gerais', None, None, None, None, None)
# (71364, 71364, '2019-10-13', 'Entre 50 a 61 anos', 'Padre Carvalho', 'Minas Gerais', None, None, None, None, None)
# (71738, 71738, '2020-12-31', 'Entre 22 a 27 anos', 'Nova Guataporanga', 'São Paulo', None, None, None, None, None)
# (71823, 71823, '2020-11-17', 'Mais de 70 anos', 'São Gabriel', 'Bahia', None, None, None, None, None)
# (71864, 71864, '2021-03-30', 'Entre 22 a 27 anos', 'Santa Bárbara do Monte Verde', 'Minas Gerais', None, None, None, None, None)
# (72112, 72112, '2021-01-13', 'Entre 28 a 36 anos', 'Comendador Levy Gasparian', 'Rio de Janeiro', None, None, None, None, None)
# (72273, 72273, '2020-05-10', 'Entre 22 a 27 anos', 'Veredinha', 'Minas Gerais', None, None, None, None, None)
# (72483, 72483, '2019-06-07', 'Entre 22 a 27 anos', 'Arandu', 'São Paulo', None, None, None, None, None)
# (72570, 72570, '2021-05-03', 'Entre 22 a 27 anos', 'Ribeirão Claro', 'Paraná', None, None, None, None, None)
# (72762, 72762, '2020-01-07', 'Mais de 70 anos', 'Bom Sucesso de Itararé', 'São Paulo', None, None, None, None, None)
# (73238, 73238, '2019-01-25', 'Entre 22 a 27 anos', 'São Tomás de Aquino', 'Minas Gerais', None, None, None, None, None)
# (74056, 74056, '2019-01-07', 'Entre 10 a 15 anos', 'Chapada de Areia', 'Tocantins', None, None, None, None, None)
# (74112, 74112, '2020-02-23', 'Entre 22 a 27 anos', 'Miguelópolis', 'São Paulo', None, None, None, None, None)
# (75257, 75257, '2020-02-22', 'Entre 22 a 27 anos', 'Bom Sucesso do Sul', 'Paraná', None, None, None, None, None)
# (75451, 75451, '2020-01-28', 'Entre 10 a 15 anos', 'Monsenhor Tabosa', 'Ceará', None, None, None, None, None)
# (75857, 75857, '2019-10-15', 'Entre 22 a 27 anos', 'Cacimbas', 'Paraíba', None, None, None, None, None)
# (76006, 76006, '2019-11-18', 'Entre 28 a 36 anos', 'Malhada dos Bois', 'Sergipe', None, None, None, None, None)
# (76528, 76528, '2019-09-26', 'Entre 28 a 36 anos', 'Ibiaí', 'Minas Gerais', None, None, None, None, None)
# (76536, 76536, '2019-01-18', 'Entre 28 a 36 anos', 'Cafelândia', 'Paraná', None, None, None, None, None)
# (76595, 76595, '2020-11-20', 'Entre 50 a 61 anos', 'Pilar', 'Alagoas', None, None, None, None, None)
# (76633, 76633, '2020-04-20', 'Entre 50 a 61 anos', 'Sete Quedas', 'Mato Grosso do Sul', None, None, None, None, None)
# (76658, 76658, '2019-02-06', 'Entre 10 a 15 anos', 'Luislândia', 'Minas Gerais', None, None, None, None, None)
# (76742, 76742, '2021-03-24', 'Entre 28 a 36 anos', 'São Valentim', 'Rio Grande do Sul', None, None, None, None, None)
# (76899, 76899, '2019-03-28', 'Entre 22 a 27 anos', 'Ribeirão do Pinhal', 'Paraná', None, None, None, None, None)
# (77695, 77695, '2019-04-01', 'Entre 16 a 21 anos', 'Fronteira', 'Minas Gerais', None, None, None, None, None)
# (77858, 77858, '2019-05-05', 'Mais de 70 anos', 'Caxias do Sul', 'Rio Grande do Sul', None, None, None, None, None)
# (78916, 78916, '2019-09-25', 'Entre 22 a 27 anos', 'Engenho Velho', 'Rio Grande do Sul', None, None, None, None, None)
# (79061, 79061, '2021-01-26', 'Entre 37 a 49 anos', 'Corumbá', 'Mato Grosso do Sul', None, None, None, None, None)
# (79817, 79817, '2019-10-10', 'Entre 28 a 36 anos', 'Rio do Fogo', 'Rio Grande do Norte', None, None, None, None, None)
# (80683, 80683, '2021-06-02', 'Entre 10 a 15 anos', 'Dionísio Cerqueira', 'Santa Catarina', None, None, None, None, None)
# (80684, 80684, '2021-06-29', 'Entre 22 a 27 anos', 'Colinas', 'Maranhão', None, None, None, None, None)
# (80781, 80781, '2020-03-10', 'Entre 22 a 27 anos', 'Ametista do Sul', 'Rio Grande do Sul', None, None, None, None, None)
# (80934, 80934, '2021-07-06', 'Entre 22 a 27 anos', 'Mara Rosa', 'Goiás', None, None, None, None, None)
# (81676, 81676, '2019-08-31', 'Entre 28 a 36 anos', 'Marzagão', 'Goiás', None, None, None, None, None)
# (82013, 82013, '2019-02-16', 'Entre 28 a 36 anos', 'Bandeira do Sul', 'Minas Gerais', None, None, None, None, None)
# (82192, 82192, '2020-12-13', 'Entre 22 a 27 anos', 'Camanducaia', 'Minas Gerais', None, None, None, None, None)
# (82197, 82197, '2019-12-12', 'Entre 10 a 15 anos', 'Romaria', 'Minas Gerais', None, None, None, None, None)
# (82414, 82414, '2020-06-09', 'Entre 28 a 36 anos', 'Vila Boa', 'Goiás', None, None, None, None, None)
# (82532, 82532, '2019-06-08', 'Entre 28 a 36 anos', 'São José', 'Santa Catarina', None, None, None, None, None)
# (82620, 82620, '2019-06-02', 'Entre 62 a 70 anos', 'Cianorte', 'Paraná', None, None, None, None, None)
# (83402, 83402, '2019-10-28', 'Entre 50 a 61 anos', 'Santa Clara do Sul', 'Rio Grande do Sul', None, None, None, None, None)
# (83718, 83718, '2021-01-21', 'Entre 50 a 61 anos', 'São Miguel dos Milagres', 'Alagoas', None, None, None, None, None)
# (84106, 84106, '2021-07-20', 'Entre 28 a 36 anos', 'Bonfim do Piauí', 'Piauí', None, None, None, None, None)
# (84364, 84364, '2020-09-20', 'Entre 37 a 49 anos', 'Terra Roxa', 'Paraná', None, None, None, None, None)
# (84400, 84400, '2019-12-19', 'Entre 37 a 49 anos', 'Pindorama do Tocantins', 'Tocantins', None, None, None, None, None)
# (85472, 85472, '2019-08-14', 'Entre 28 a 36 anos', 'Três Lagoas', 'Mato Grosso do Sul', None, None, None, None, None)
# (86504, 86504, '2019-01-08', 'Entre 37 a 49 anos', 'Serranópolis', 'Goiás', None, None, None, None, None)
# (86667, 86667, '2019-10-31', 'Entre 10 a 15 anos', 'Elói Mendes', 'Minas Gerais', None, None, None, None, None)
# (87120, 87120, '2020-03-22', 'Entre 37 a 49 anos', 'Camanducaia', 'Minas Gerais', None, None, None, None, None)
# (87284, 87284, '2020-01-04', 'Entre 10 a 15 anos', 'Matriz de Camaragibe', 'Alagoas', None, None, None, None, None)
# (87909, 87909, '2020-03-31', 'Entre 50 a 61 anos', 'Juiz de Fora', 'Minas Gerais', None, None, None, None, None)
# (88107, 88107, '2021-04-29', 'Entre 16 a 21 anos', 'Barra de São Miguel', 'Alagoas', None, None, None, None, None)
# (88389, 88389, '2020-08-25', 'Mais de 70 anos', 'Piranguçu', 'Minas Gerais', None, None, None, None, None)
# (88698, 88698, '2020-08-26', 'Entre 28 a 36 anos', 'Luiz Alves', 'Santa Catarina', None, None, None, None, None)
# (88719, 88719, '2020-10-01', 'Entre 10 a 15 anos', 'Nova Trento', 'Santa Catarina', None, None, None, None, None)
# (88731, 88731, '2019-02-16', 'Entre 37 a 49 anos', 'Paraíso das Águas', 'Mato Grosso do Sul', None, None, None, None, None)
# (88883, 88883, '2020-04-14', 'Entre 37 a 49 anos', 'Tapira', 'Paraná', None, None, None, None, None)
# (88977, 88977, '2020-01-02', 'Entre 50 a 61 anos', 'Cristalândia do Piauí', 'Piauí', None, None, None, None, None)
# (89064, 89064, '2020-12-12', 'Entre 28 a 36 anos', 'Caparaó', 'Minas Gerais', None, None, None, None, None)
# (89068, 89068, '2019-03-04', 'Entre 10 a 15 anos', 'Inhangapi', 'Pará', None, None, None, None, None)
# (89448, 89448, '2019-12-22', 'Entre 22 a 27 anos', 'Toropi', 'Rio Grande do Sul', None, None, None, None, None)
# (89620, 89620, '2019-06-15', 'Entre 37 a 49 anos', 'Balneário Arroio do Silva', 'Santa Catarina', None, None, None, None, None)
# (91155, 91155, '2019-01-13', 'Entre 22 a 27 anos', 'Resende', 'Rio de Janeiro', None, None, None, None, None)
# (91773, 91773, '2020-02-25', 'Entre 50 a 61 anos', 'Dores do Indaiá', 'Minas Gerais', None, None, None, None, None)
# (91933, 91933, '2020-01-04', 'Entre 50 a 61 anos', 'Rio Bonito do Iguaçu', 'Paraná', None, None, None, None, None)
# (92722, 92722, '2019-01-29', 'Entre 16 a 21 anos', 'Garopaba', 'Santa Catarina', None, None, None, None, None)
# (94812, 94812, '2019-11-13', 'Mais de 70 anos', 'Morro da Fumaça', 'Santa Catarina', None, None, None, None, None)
# (94898, 94898, '2021-03-17', 'Entre 22 a 27 anos', 'São João do Manteninha', 'Minas Gerais', None, None, None, None, None)
# (95089, 95089, '2020-12-31', 'Entre 22 a 27 anos', 'Loreto', 'Maranhão', None, None, None, None, None)
# (95221, 95221, '2021-04-02', 'Entre 62 a 70 anos', 'Peixe-Boi', 'Pará', None, None, None, None, None)
# (95676, 95676, '2019-03-31', 'Entre 62 a 70 anos', 'Nicolau Vergueiro', 'Rio Grande do Sul', None, None, None, None, None)
# (95889, 95889, '2020-05-31', 'Entre 10 a 15 anos', 'Ituberá', 'Bahia', None, None, None, None, None)
# (96379, 96379, '2019-07-10', 'Entre 28 a 36 anos', 'Paim Filho', 'Rio Grande do Sul', None, None, None, None, None)
# (97103, 97103, '2019-03-18', 'Entre 62 a 70 anos', 'Jundiaí', 'São Paulo', None, None, None, None, None)
# (97362, 97362, '2019-05-21', 'Entre 37 a 49 anos', 'Orleans', 'Santa Catarina', None, None, None, None, None)
# (97393, 97393, '2019-11-03', 'Entre 10 a 15 anos', 'Aurelino Leal', 'Bahia', None, None, None, None, None)
# (97553, 97553, '2019-08-22', 'Mais de 70 anos', 'Novorizonte', 'Minas Gerais', None, None, None, None, None)
# (98866, 98866, '2020-12-20', 'Entre 50 a 61 anos', 'Cururupu', 'Maranhão', None, None, None, None, None)
# (98882, 98882, '2019-05-12', 'Entre 62 a 70 anos', 'Remanso', 'Bahia', None, None, None, None, None)
# (99084, 99084, '2020-08-06', 'Entre 22 a 27 anos', 'Itápolis', 'São Paulo', None, None, None, None, None)
# (99189, 99189, '2019-07-12', 'Entre 28 a 36 anos', 'Barcarena', 'Pará', None, None, None, None, None)
# (99244, 99244, '2020-05-02', 'Mais de 70 anos', 'Três Corações', 'Minas Gerais', None, None, None, None, None)
# (99625, 99625, '2020-10-27', 'Entre 28 a 36 anos', 'Iraí de Minas', 'Minas Gerais', None, None, None, None, None)
# (99694, 99694, '2021-02-09', 'Entre 62 a 70 anos', 'Nova Iguaçu', 'Rio de Janeiro', None, None, None, None, None)
# (100067, 100067, '2019-06-24', 'Entre 50 a 61 anos', 'Coronel João Sá', 'Bahia', None, None, None, None, None)
# (101157, 101157, '2019-08-24', 'Entre 62 a 70 anos', 'Tiros', 'Minas Gerais', None, None, None, None, None)
# (101231, 101231, '2020-05-29', 'Entre 28 a 36 anos', 'Teixeiras', 'Minas Gerais', None, None, None, None, None)
# (101560, 101560, '2020-03-09', 'Entre 22 a 27 anos', 'Siqueira Campos', 'Paraná', None, None, None, None, None)
# (101683, 101683, '2019-06-03', 'Entre 16 a 21 anos', 'Cururupu', 'Maranhão', None, None, None, None, None)
# (101903, 101903, '2020-03-19', 'Entre 50 a 61 anos', 'Trindade', 'Pernambuco', None, None, None, None, None)
# (102264, 102264, '2021-07-09', 'Entre 50 a 61 anos', 'Silves', 'Amazonas', None, None, None, None, None)
# (102874, 102874, '2020-11-11', 'Entre 16 a 21 anos', 'Faria Lemos', 'Minas Gerais', None, None, None, None, None)
# (103285, 103285, '2019-04-17', 'Entre 62 a 70 anos', 'Piumhi', 'Minas Gerais', None, None, None, None, None)
# (103636, 103636, '2019-09-11', 'Entre 22 a 27 anos', 'Iati', 'Pernambuco', None, None, None, None, None)
# (104324, 104324, '2020-05-06', 'Entre 10 a 15 anos', 'Anicuns', 'Goiás', None, None, None, None, None)
# (104987, 104987, '2019-07-02', 'Entre 50 a 61 anos', 'Anhanguera', 'Goiás', None, None, None, None, None)
# (105037, 105037, '2020-01-22', 'Entre 10 a 15 anos', 'Lagoinha do Piauí', 'Piauí', None, None, None, None, None)
# (105715, 105715, '2019-09-02', 'Entre 62 a 70 anos', 'Ariranha do Ivaí', 'Paraná', None, None, None, None, None)
# (105931, 105931, '2019-10-16', 'Entre 10 a 15 anos', 'Marabá', 'Pará', None, None, None, None, None)
# (106265, 106265, '2020-11-14', 'Entre 10 a 15 anos', 'Espírito Santo do Turvo', 'São Paulo', None, None, None, None, None)
# (106316, 106316, '2019-02-18', 'Entre 62 a 70 anos', 'Nova Esperança do Sul', 'Rio Grande do Sul', None, None, None, None, None)
# (106810, 106810, '2021-06-18', 'Entre 62 a 70 anos', 'Santa Branca', 'São Paulo', None, None, None, None, None)
# (107025, 107025, '2020-10-01', 'Entre 16 a 21 anos', 'Carmópolis', 'Sergipe', None, None, None, None, None)
# (107257, 107257, '2021-01-10', 'Mais de 70 anos', 'Esmeraldas', 'Minas Gerais', None, None, None, None, None)
# (107291, 107291, '2020-07-07', 'Entre 22 a 27 anos', 'Belmonte', 'Bahia', None, None, None, None, None)
# (107944, 107944, '2020-12-19', 'Entre 50 a 61 anos', 'Vilhena', 'Rondônia', None, None, None, None, None)
# (108216, 108216, '2020-05-09', 'Mais de 70 anos', 'Itabirinha', 'Minas Gerais', None, None, None, None, None)
# (108284, 108284, '2019-11-14', 'Entre 28 a 36 anos', 'Coronel Ezequiel', 'Rio Grande do Norte', None, None, None, None, None)
# (108440, 108440, '2019-12-03', 'Entre 10 a 15 anos', 'Mirangaba', 'Bahia', None, None, None, None, None)
# (109106, 109106, '2020-12-27', 'Entre 62 a 70 anos', 'Itumbiara', 'Goiás', None, None, None, None, None)
# (109128, 109128, '2020-01-28', 'Entre 16 a 21 anos', 'Cascavel', 'Paraná', None, None, None, None, None)
# (109755, 109755, '2019-06-27', 'Mais de 70 anos', 'Águas Formosas', 'Minas Gerais', None, None, None, None, None)
# (109860, 109860, '2019-01-19', 'Entre 10 a 15 anos', 'Ilha Solteira', 'São Paulo', None, None, None, None, None)
# (111170, 111170, '2019-01-15', 'Mais de 70 anos', 'Manoel Viana', 'Rio Grande do Sul', None, None, None, None, None)
# (111327, 111327, '2021-06-27', 'Entre 62 a 70 anos', 'Manoel Vitorino', 'Bahia', None, None, None, None, None)
# (111424, 111424, '2019-03-04', 'Entre 28 a 36 anos', 'Votuporanga', 'São Paulo', None, None, None, None, None)
# (112333, 112333, '2019-12-04', 'Entre 28 a 36 anos', 'Novo Oriente do Piauí', 'Piauí', None, None, None, None, None)
# (112339, 112339, '2020-01-26', 'Entre 10 a 15 anos', 'Vermelho Novo', 'Minas Gerais', None, None, None, None, None)
# (112650, 112650, '2021-07-24', 'Entre 37 a 49 anos', 'São João do Soter', 'Maranhão', None, None, None, None, None)
# (113360, 113360, '2020-12-17', 'Entre 10 a 15 anos', 'Vargem Grande do Sul', 'São Paulo', None, None, None, None, None)
# (114007, 114007, '2020-05-03', 'Entre 62 a 70 anos', 'São Valentim', 'Rio Grande do Sul', None, None, None, None, None)
# (114415, 114415, '2021-02-08', 'Entre 62 a 70 anos', 'Cambuci', 'Rio de Janeiro', None, None, None, None, None)
# (114417, 114417, '2020-11-22', 'Entre 50 a 61 anos', 'Teófilo Otoni', 'Minas Gerais', None, None, None, None, None)
# (114775, 114775, '2020-08-09', 'Mais de 70 anos', 'São João do Carú', 'Maranhão', None, None, None, None, None)
# (115032, 115032, '2019-10-13', 'Entre 62 a 70 anos', 'Bom Princípio', 'Rio Grande do Sul', None, None, None, None, None)
# (115036, 115036, '2020-06-26', 'Entre 22 a 27 anos', 'Floresta', 'Pernambuco', None, None, None, None, None)
# (115202, 115202, '2020-09-10', 'Entre 50 a 61 anos', 'Água Doce', 'Santa Catarina', None, None, None, None, None)
# (115617, 115617, '2019-09-09', 'Entre 22 a 27 anos', 'Vila Lângaro', 'Rio Grande do Sul', None, None, None, None, None)
# (115911, 115911, '2021-05-01', 'Entre 28 a 36 anos', 'Encruzilhada', 'Bahia', None, None, None, None, None)
# (116325, 116325, '2020-02-23', 'Entre 16 a 21 anos', 'Itapiranga', 'Santa Catarina', None, None, None, None, None)
# (116597, 116597, '2019-02-15', 'Entre 62 a 70 anos', 'Inhambupe', 'Bahia', None, None, None, None, None)
# (116922, 116922, '2019-05-03', 'Entre 16 a 21 anos', 'Dueré', 'Tocantins', None, None, None, None, None)
# (117070, 117070, '2020-10-06', 'Entre 16 a 21 anos', 'Damolândia', 'Goiás', None, None, None, None, None)
# (117330, 117330, '2019-05-17', 'Entre 28 a 36 anos', 'Vila Flores', 'Rio Grande do Sul', None, None, None, None, None)
# (118226, 118226, '2020-02-23', 'Entre 37 a 49 anos', 'Santo Antônio do Leste', 'Mato Grosso', None, None, None, None, None)
# (118389, 118389, '2021-06-26', 'Entre 22 a 27 anos', 'Crato', 'Ceará', None, None, None, None, None)
# (119342, 119342, '2019-02-10', 'Entre 16 a 21 anos', 'Reserva', 'Paraná', None, None, None, None, None)
# (119806, 119806, '2019-11-08', 'Entre 50 a 61 anos', 'Curralinhos', 'Piauí', None, None, None, None, None)
# (120304, 120304, '2020-07-31', 'Entre 50 a 61 anos', 'São Salvador do Tocantins', 'Tocantins', None, None, None, None, None)
# (120679, 120679, '2019-02-16', 'Entre 50 a 61 anos', 'Capitólio', 'Minas Gerais', None, None, None, None, None)
# (121381, 121381, '2019-07-13', 'Entre 28 a 36 anos', 'Goiatins', 'Tocantins', None, None, None, None, None)
# (121964, 121964, '2020-12-12', 'Entre 28 a 36 anos', 'Dilermando de Aguiar', 'Rio Grande do Sul', None, None, None, None, None)
# (122173, 122173, '2019-03-15', 'Mais de 70 anos', 'Xanxerê', 'Santa Catarina', None, None, None, None, None)
# (122830, 122830, '2020-11-16', 'Entre 50 a 61 anos', 'São Miguel Arcanjo', 'São Paulo', None, None, None, None, None)
# (123195, 123195, '2019-07-18', 'Entre 16 a 21 anos', 'Aracruz', 'Espírito Santo', None, None, None, None, None)
# (123326, 123326, '2019-01-10', 'Mais de 70 anos', 'Riachão do Jacuípe', 'Bahia', None, None, None, None, None)
# (123350, 123350, '2019-05-25', 'Entre 28 a 36 anos', 'Panambi', 'Rio Grande do Sul', None, None, None, None, None)
# (123602, 123602, '2021-05-05', 'Mais de 70 anos', 'Valença', 'Rio de Janeiro', None, None, None, None, None)
# (124194, 124194, '2019-12-05', 'Mais de 70 anos', 'Candeias', 'Bahia', None, None, None, None, None)
# (124410, 124410, '2020-09-04', 'Entre 28 a 36 anos', 'Fagundes Varela', 'Rio Grande do Sul', None, None, None, None, None)
# (125136, 125136, '2019-03-07', 'Mais de 70 anos', 'Matinhos', 'Paraná', None, None, None, None, None)
# (125831, 125831, '2021-03-26', 'Entre 50 a 61 anos', 'Araguaína', 'Tocantins', None, None, None, None, None)
# (126064, 126064, '2019-04-26', 'Entre 10 a 15 anos', 'Saboeiro', 'Ceará', None, None, None, None, None)
# (126712, 126712, '2020-02-23', 'Mais de 70 anos', 'Xambrê', 'Paraná', None, None, None, None, None)
# (128030, 128030, '2020-05-31', 'Entre 10 a 15 anos', 'Gurinhém', 'Paraíba', None, None, None, None, None)
# (128094, 128094, '2021-06-22', 'Entre 37 a 49 anos', 'Cerquilho', 'São Paulo', None, None, None, None, None)
# (129150, 129150, '2020-08-08', 'Entre 10 a 15 anos', 'Indiaroba', 'Sergipe', None, None, None, None, None)
# (129393, 129393, '2019-11-26', 'Entre 10 a 15 anos', 'Santana de Pirapama', 'Minas Gerais', None, None, None, None, None)
# (129612, 129612, '2020-08-09', 'Entre 50 a 61 anos', 'Ipaussu', 'São Paulo', None, None, None, None, None)
# (130245, 130245, '2021-01-03', 'Entre 10 a 15 anos', 'Borá', 'São Paulo', None, None, None, None, None)
# (130561, 130561, '2019-09-18', 'Entre 16 a 21 anos', 'Bujaru', 'Pará', None, None, None, None, None)
# (130752, 130752, '2020-08-21', 'Mais de 70 anos', 'Catalão', 'Goiás', None, None, None, None, None)
# (130809, 130809, '2020-11-28', 'Entre 22 a 27 anos', 'Jurema', 'Pernambuco', None, None, None, None, None)
# (130873, 130873, '2020-06-24', 'Entre 10 a 15 anos', 'Triunfo', 'Pernambuco', None, None, None, None, None)
# (131117, 131117, '2020-11-27', 'Entre 28 a 36 anos', 'São Francisco de Assis do Piauí', 'Piauí', None, None, None, None, None)
# (132311, 132311, '2020-03-10', 'Entre 50 a 61 anos', 'Jaguaribara', 'Ceará', None, None, None, None, None)
# (132745, 132745, '2021-05-21', 'Mais de 70 anos', 'Santa Helena de Goiás', 'Goiás', None, None, None, None, None)
# (133048, 133048, '2020-06-15', 'Entre 28 a 36 anos', 'São João Batista', 'Santa Catarina', None, None, None, None, None)
# (133447, 133447, '2019-08-16', 'Entre 62 a 70 anos', 'Peritoró', 'Maranhão', None, None, None, None, None)
# (134349, 134349, '2019-12-02', 'Entre 22 a 27 anos', 'Pareci Novo', 'Rio Grande do Sul', None, None, None, None, None)
# (134887, 134887, '2021-05-27', 'Entre 16 a 21 anos', 'Bannach', 'Pará', None, None, None, None, None)
# (135062, 135062, '2019-11-07', 'Entre 62 a 70 anos', 'Aracitaba', 'Minas Gerais', None, None, None, None, None)
# (135107, 135107, '2020-01-09', 'Entre 16 a 21 anos', 'Aloândia', 'Goiás', None, None, None, None, None)
# (135122, 135122, '2020-03-21', 'Entre 37 a 49 anos', 'Caxambu', 'Minas Gerais', None, None, None, None, None)
# (135148, 135148, '2021-04-19', 'Entre 62 a 70 anos', 'Funilândia', 'Minas Gerais', None, None, None, None, None)
# (136381, 136381, '2019-01-10', 'Entre 28 a 36 anos', 'Guarujá do Sul', 'Santa Catarina', None, None, None, None, None)
# (136571, 136571, '2020-07-07', 'Entre 28 a 36 anos', 'São Francisco de Assis do Piauí', 'Piauí', None, None, None, None, None)
# (136619, 136619, '2019-03-25', 'Entre 16 a 21 anos', 'Capão do Cipó', 'Rio Grande do Sul', None, None, None, None, None)
# (136648, 136648, '2019-09-22', 'Entre 50 a 61 anos', 'Paranaíta', 'Mato Grosso', None, None, None, None, None)
# (136930, 136930, '2019-07-29', 'Entre 50 a 61 anos', 'Ereré', 'Ceará', None, None, None, None, None)
# (137196, 137196, '2019-03-05', 'Entre 22 a 27 anos', 'Conceição do Jacuípe', 'Bahia', None, None, None, None, None)
# (137339, 137339, '2019-12-09', 'Entre 62 a 70 anos', 'Turiúba', 'São Paulo', None, None, None, None, None)
# (137832, 137832, '2020-05-11', 'Entre 50 a 61 anos', 'Canitar', 'São Paulo', None, None, None, None, None)
# (137982, 137982, '2019-12-01', 'Entre 22 a 27 anos', 'Cromínia', 'Goiás', None, None, None, None, None)
# (139439, 139439, '2020-01-26', 'Entre 10 a 15 anos', 'Lagoa de São Francisco', 'Piauí', None, None, None, None, None)
# (139831, 139831, '2021-06-14', 'Entre 62 a 70 anos', 'São Miguel das Missões', 'Rio Grande do Sul', None, None, None, None, None)
# (140009, 140009, '2020-07-12', 'Entre 28 a 36 anos', 'Guaraçaí', 'São Paulo', None, None, None, None, None)
# (140569, 140569, '2019-07-25', 'Entre 10 a 15 anos', 'Sales', 'São Paulo', None, None, None, None, None)
# (140818, 140818, '2020-01-01', 'Mais de 70 anos', 'Armação dos Búzios', 'Rio de Janeiro', None, None, None, None, None)
# (141113, 141113, '2020-07-30', 'Entre 50 a 61 anos', 'São Luiz', 'Roraima', None, None, None, None, None)
# (141476, 141476, '2019-11-28', 'Entre 16 a 21 anos', 'Manoel Viana', 'Rio Grande do Sul', None, None, None, None, None)
# (141513, 141513, '2020-01-17', 'Entre 28 a 36 anos', 'Guaribas', 'Piauí', None, None, None, None, None)
# (141610, 141610, '2019-06-09', 'Entre 50 a 61 anos', 'Portalegre', 'Rio Grande do Norte', None, None, None, None, None)
# (141711, 141711, '2019-09-19', 'Mais de 70 anos', 'Barroquinha', 'Ceará', None, None, None, None, None)
# (141823, 141823, '2020-06-25', 'Entre 16 a 21 anos', 'Juarez Távora', 'Paraíba', None, None, None, None, None)
# (142028, 142028, '2019-02-06', 'Entre 22 a 27 anos', 'Lagoa de São Francisco', 'Piauí', None, None, None, None, None)
# (142131, 142131, '2020-03-15', 'Mais de 70 anos', 'Nova Ponte', 'Minas Gerais', None, None, None, None, None)
# (142562, 142562, '2021-07-31', 'Entre 16 a 21 anos', 'Cabrália Paulista', 'São Paulo', None, None, None, None, None)
# (142700, 142700, '2020-12-24', 'Entre 37 a 49 anos', 'Firmino Alves', 'Bahia', None, None, None, None, None)
# (142924, 142924, '2019-03-12', 'Entre 16 a 21 anos', 'Elesbão Veloso', 'Piauí', None, None, None, None, None)
# (143257, 143257, '2020-11-09', 'Entre 16 a 21 anos', 'Agrolândia', 'Santa Catarina', None, None, None, None, None)
# (143992, 143992, '2019-07-03', 'Mais de 70 anos', 'Governador Archer', 'Maranhão', None, None, None, None, None)
# (144088, 144088, '2020-03-08', 'Entre 62 a 70 anos', 'Vera Cruz', 'Rio Grande do Norte', None, None, None, None, None)
# (144165, 144165, '2019-03-12', 'Entre 37 a 49 anos', 'Tutóia', 'Maranhão', None, None, None, None, None)
# (144367, 144367, '2019-03-08', 'Entre 37 a 49 anos', 'Anicuns', 'Goiás', None, None, None, None, None)
# (144622, 144622, '2021-04-15', 'Entre 62 a 70 anos', 'Senador Elói de Souza', 'Rio Grande do Norte', None, None, None, None, None)
# (145374, 145374, '2019-12-11', 'Entre 10 a 15 anos', 'São José dos Ausentes', 'Rio Grande do Sul', None, None, None, None, None)
# (145396, 145396, '2019-05-26', 'Entre 10 a 15 anos', 'Nova União', 'Rondônia', None, None, None, None, None)
# (146141, 146141, '2019-09-22', 'Entre 37 a 49 anos', 'Almirante Tamandaré', 'Paraná', None, None, None, None, None)
# (147671, 147671, '2019-05-09', 'Entre 10 a 15 anos', 'São Bernardino', 'Santa Catarina', None, None, None, None, None)
# (148356, 148356, '2021-02-16', 'Entre 50 a 61 anos', 'Maceió', 'Alagoas', None, None, None, None, None)
# (148392, 148392, '2020-07-27', 'Entre 28 a 36 anos', 'Santa Maria do Herval', 'Rio Grande do Sul', None, None, None, None, None)
# (148713, 148713, '2021-07-28', 'Entre 10 a 15 anos', 'Canitar', 'São Paulo', None, None, None, None, None)
# (148889, 148889, '2021-03-15', 'Entre 37 a 49 anos', 'Jardinópolis', 'São Paulo', None, None, None, None, None)
# (148903, 148903, '2020-12-27', 'Entre 16 a 21 anos', 'Ventania', 'Paraná', None, None, None, None, None)
# (149257, 149257, '2021-05-11', 'Entre 50 a 61 anos', 'Águas Lindas de Goiás', 'Goiás', None, None, None, None, None)
# (149726, 149726, '2020-03-06', 'Entre 16 a 21 anos', 'Cacaulândia', 'Rondônia', None, None, None, None, None)
# (150206, 150206, '2020-02-24', 'Entre 10 a 15 anos', 'Engenheiro Paulo de Frontin', 'Rio de Janeiro', None, None, None, None, None)
# (150330, 150330, '2021-06-24', 'Entre 37 a 49 anos', 'Regente Feijó', 'São Paulo', None, None, None, None, None)
# (150666, 150666, '2019-01-22', 'Entre 16 a 21 anos', 'Dom Expedito Lopes', 'Piauí', None, None, None, None, None)
# (150835, 150835, '2019-10-16', 'Entre 28 a 36 anos', 'Cordeiro', 'Rio de Janeiro', None, None, None, None, None)
# (151330, 151330, '2021-04-19', 'Mais de 70 anos', 'Santo Antônio do Jacinto', 'Minas Gerais', None, None, None, None, None)
# (152221, 152221, '2019-06-07', 'Entre 16 a 21 anos', 'Doverlândia', 'Goiás', None, None, None, None, None)
# (152237, 152237, '2019-03-10', 'Entre 22 a 27 anos', 'Faro', 'Pará', None, None, None, None, None)
# (152327, 152327, '2019-01-09', 'Entre 28 a 36 anos', 'Maranhãozinho', 'Maranhão', None, None, None, None, None)
# (153687, 153687, '2019-01-01', 'Mais de 70 anos', 'Teixeira de Freitas', 'Bahia', None, None, None, None, None)
# (154196, 154196, '2020-09-16', 'Entre 28 a 36 anos', 'Parazinho', 'Rio Grande do Norte', None, None, None, None, None)
# (154413, 154413, '2020-05-20', 'Entre 16 a 21 anos', 'Tangará', 'Rio Grande do Norte', None, None, None, None, None)
# ...
# (97763, 97763, '2018-02-18', 'Mais de 70 anos', 'Chapada da Natividade', 'Tocantins', None, None, None, None, None)
# (52813, 52813, '2020-12-30', 'Entre 50 a 61 anos', 'Floresta Azul', 'Bahia', None, None, None, None, None)
# (37056, 37056, '2020-01-22', 'Entre 50 a 61 anos', 'Ribeirão Vermelho', 'Minas Gerais', None, None, None, None, None)
# (12364, 12364, '2020-02-03', 'Mais de 70 anos', 'Pedro do Rosário', 'Maranhão', None, None, None, None, None)
# (37907, 37907, '2019-10-26', 'Entre 10 a 15 anos', 'Olindina', 'Bahia', None, None, None, None, None)
# (29792, 29792, '2019-07-08', 'Entre 62 a 70 anos', 'Várzea do Poço', 'Bahia', None, None, None, None, None)
# (9691, 9691, '2018-03-15', 'Entre 62 a 70 anos', 'Diamante', 'Paraíba', None, None, None, None, None)
# (50948, 50948, '2020-12-16', 'Mais de 70 anos', 'Angélica', 'Mato Grosso do Sul', None, None, None, None, None)
# (6609, 6609, '2020-06-05', 'Entre 37 a 49 anos', 'Sapé', 'Paraíba', None, None, None, None, None)
# (25889, 25889, '2018-02-13', 'Mais de 70 anos', 'Alagoinha', 'Pernambuco', None, None, None, None, None)
# (33087, 33087, '2019-09-15', 'Entre 28 a 36 anos', 'Amaporã', 'Paraná', None, None, None, None, None)
# (19015, 19015, '2020-03-11', 'Entre 16 a 21 anos', 'Lagoa Formosa', 'Minas Gerais', None, None, None, None, None)
# (40776, 40776, '2020-07-26', 'Mais de 70 anos', 'Vitória do Xingu', 'Pará', None, None, None, None, None)
# (85230, 85230, '2021-02-03', 'Entre 16 a 21 anos', 'Formosa da Serra Negra', 'Maranhão', None, None, None, None, None)
# (40149, 40149, '2021-02-03', 'Mais de 70 anos', 'Marcelino Ramos', 'Rio Grande do Sul', None, None, None, None, None)
# (6702, 6702, '2019-12-08', 'Entre 37 a 49 anos', 'Palmas', 'Paraná', None, None, None, None, None)
# (94058, 94058, '2019-10-31', 'Entre 28 a 36 anos', 'Mansidão', 'Bahia', None, None, None, None, None)
# (32881, 32881, '2018-09-04', 'Entre 22 a 27 anos', 'Joca Marques', 'Piauí', None, None, None, None, None)
# (18602, 18602, '2021-04-18', 'Entre 50 a 61 anos', 'Coqueiro Baixo', 'Rio Grande do Sul', None, None, None, None, None)
# (85012, 85012, '2019-06-12', 'Entre 10 a 15 anos', 'Lupércio', 'São Paulo', None, None, None, None, None)
# (56292, 56292, '2020-02-25', 'Entre 22 a 27 anos', 'Dom Expedito Lopes', 'Piauí', None, None, None, None, None)
# (52105, 52105, '2018-07-12', 'Entre 50 a 61 anos', 'Boa Vista', 'Paraíba', None, None, None, None, None)
# (67360, 67360, '2020-07-20', 'Entre 50 a 61 anos', 'Belmonte', 'Bahia', None, None, None, None, None)
# (55093, 55093, '2020-09-01', 'Entre 16 a 21 anos', 'Palmas de Monte Alto', 'Bahia', None, None, None, None, None)
# (48491, 48491, '2019-06-18', 'Entre 16 a 21 anos', 'São Vicente do Seridó', 'Paraíba', None, None, None, None, None)
# (99698, 99698, '2020-06-13', 'Entre 16 a 21 anos', 'Campo Largo', 'Paraná', None, None, None, None, None)
# (17798, 17798, '2018-11-26', 'Entre 37 a 49 anos', 'São Miguel dos Milagres', 'Alagoas', None, None, None, None, None)
# (10495, 10495, '2018-08-29', 'Entre 16 a 21 anos', 'Ponte Branca', 'Mato Grosso', None, None, None, None, None)
# (24070, 24070, '2018-04-02', 'Entre 22 a 27 anos', 'Rancho Queimado', 'Santa Catarina', None, None, None, None, None)
# (34924, 34924, '2020-05-26', 'Entre 10 a 15 anos', 'Urupá', 'Rondônia', None, None, None, None, None)
# (74314, 74314, '2020-11-16', 'Entre 50 a 61 anos', 'Quixeramobim', 'Ceará', None, None, None, None, None)
# (52993, 52993, '2019-11-07', 'Entre 50 a 61 anos', 'Vertente do Lério', 'Pernambuco', None, None, None, None, None)
# (52393, 52393, '2020-04-10', 'Entre 62 a 70 anos', 'Mallet', 'Paraná', None, None, None, None, None)
# (77030, 77030, '2020-06-12', 'Entre 62 a 70 anos', 'Ouro Preto do Oeste', 'Rondônia', None, None, None, None, None)
# (78203, 78203, '2018-01-21', 'Mais de 70 anos', 'Ilhabela', 'São Paulo', None, None, None, None, None)
# (68847, 68847, '2018-04-25', 'Entre 50 a 61 anos', 'Valparaíso de Goiás', 'Goiás', None, None, None, None, None)
# (5318, 5318, '2019-12-14', 'Entre 62 a 70 anos', 'Lizarda', 'Tocantins', None, None, None, None, None)
# (78598, 78598, '2018-04-09', 'Entre 37 a 49 anos', 'Taguatinga', 'Tocantins', None, None, None, None, None)
# (25798, 25798, '2021-02-01', 'Entre 37 a 49 anos', 'Gurupá', 'Pará', None, None, None, None, None)
# (56062, 56062, '2020-05-03', 'Entre 10 a 15 anos', 'São Pedro do Ivaí', 'Paraná', None, None, None, None, None)
# (84323, 84323, '2021-05-30', 'Entre 62 a 70 anos', 'Palmeirópolis', 'Tocantins', None, None, None, None, None)
# (19203, 19203, '2020-05-04', 'Entre 16 a 21 anos', 'Taiobeiras', 'Minas Gerais', None, None, None, None, None)
# (29019, 29019, '2020-05-19', 'Entre 62 a 70 anos', 'Nova Veneza', 'Santa Catarina', None, None, None, None, None)
# (93737, 93737, '2019-03-22', 'Entre 16 a 21 anos', 'Coronel Vivida', 'Paraná', None, None, None, None, None)
# (60201, 60201, '2020-07-06', 'Entre 16 a 21 anos', 'Tio Hugo', 'Rio Grande do Sul', None, None, None, None, None)
# (41275, 41275, '2019-11-06', 'Entre 50 a 61 anos', 'Tremedal', 'Bahia', None, None, None, None, None)
# (49241, 49241, '2019-02-07', 'Entre 16 a 21 anos', 'Santo Antônio de Lisboa', 'Piauí', None, None, None, None, None)
# (84850, 84850, '2019-04-01', 'Entre 28 a 36 anos', 'Capanema', 'Pará', None, None, None, None, None)
# (35390, 35390, '2019-01-05', 'Mais de 70 anos', 'Montes Claros', 'Minas Gerais', None, None, None, None, None)
# (20352, 20352, '2018-04-16', 'Entre 37 a 49 anos', 'Imbituva', 'Paraná', None, None, None, None, None)
# (79052, 79052, '2018-05-29', 'Entre 62 a 70 anos', 'Pintadas', 'Bahia', None, None, None, None, None)
# (46296, 46296, '2019-01-15', 'Entre 37 a 49 anos', 'Capinópolis', 'Minas Gerais', None, None, None, None, None)
# (11358, 11358, '2019-04-23', 'Entre 37 a 49 anos', 'Capão da Canoa', 'Rio Grande do Sul', None, None, None, None, None)
# (15691, 15691, '2018-11-07', 'Entre 22 a 27 anos', 'Imigrante', 'Rio Grande do Sul', None, None, None, None, None)
# (44126, 44126, '2019-11-25', 'Entre 10 a 15 anos', 'Quartel Geral', 'Minas Gerais', None, None, None, None, None)
# (84391, 84391, '2021-02-01', 'Mais de 70 anos', 'Rio Negrinho', 'Santa Catarina', None, None, None, None, None)
# (93699, 93699, '2018-12-05', 'Entre 16 a 21 anos', 'Aroazes', 'Piauí', None, None, None, None, None)
# (42577, 42577, '2018-02-06', 'Entre 16 a 21 anos', 'Pedrinhas Paulista', 'São Paulo', None, None, None, None, None)
# (4269, 4269, '2020-10-14', 'Entre 22 a 27 anos', 'General Carneiro', 'Mato Grosso', None, None, None, None, None)
# (22777, 22777, '2019-05-15', 'Entre 50 a 61 anos', 'Barreira', 'Ceará', None, None, None, None, None)
# (57906, 57906, '2018-03-12', 'Entre 62 a 70 anos', 'Esperantina', 'Tocantins', None, None, None, None, None)
# (18800, 18800, '2018-06-13', 'Mais de 70 anos', 'Riachão do Jacuípe', 'Bahia', None, None, None, None, None)
# (94169, 94169, '2019-06-24', 'Entre 22 a 27 anos', 'Ubaíra', 'Bahia', None, None, None, None, None)
# (61605, 61605, '2021-05-01', 'Entre 10 a 15 anos', 'Nova Santa Rosa', 'Paraná', None, None, None, None, None)
# (74851, 74851, '2021-01-12', 'Entre 16 a 21 anos', 'Gramado dos Loureiros', 'Rio Grande do Sul', None, None, None, None, None)
# (68781, 68781, '2018-01-11', 'Entre 10 a 15 anos', 'Dois Riachos', 'Alagoas', None, None, None, None, None)
# (78406, 78406, '2021-02-11', 'Entre 10 a 15 anos', 'São Sebastião do Tocantins', 'Tocantins', None, None, None, None, None)
# (82833, 82833, '2020-02-11', 'Entre 10 a 15 anos', 'Porto União', 'Santa Catarina', None, None, None, None, None)
# (31064, 31064, '2019-11-20', 'Entre 50 a 61 anos', 'São José do Cedro', 'Santa Catarina', None, None, None, None, None)
# (68058, 68058, '2019-03-30', 'Entre 62 a 70 anos', 'Caiabu', 'São Paulo', None, None, None, None, None)
# (71491, 71491, '2019-11-15', 'Entre 28 a 36 anos', 'Taperoá', 'Paraíba', None, None, None, None, None)
# (6511, 6511, '2021-03-30', 'Entre 37 a 49 anos', 'Brejolândia', 'Bahia', None, None, None, None, None)
# (30457, 30457, '2020-02-06', 'Entre 10 a 15 anos', 'Pesqueira', 'Pernambuco', None, None, None, None, None)
# (73973, 73973, '2019-12-31', 'Entre 16 a 21 anos', 'Pajeú do Piauí', 'Piauí', None, None, None, None, None)
# (31972, 31972, '2021-03-12', 'Entre 28 a 36 anos', 'Caibaté', 'Rio Grande do Sul', None, None, None, None, None)
# (26510, 26510, '2021-07-15', 'Entre 37 a 49 anos', 'São Miguel do Iguaçu', 'Paraná', None, None, None, None, None)
# (59514, 59514, '2019-03-31', 'Entre 50 a 61 anos', 'Minador do Negrão', 'Alagoas', None, None, None, None, None)
# (49295, 49295, '2019-05-12', 'Entre 37 a 49 anos', 'Buerarema', 'Bahia', None, None, None, None, None)
# (3504, 3504, '2021-06-23', 'Entre 16 a 21 anos', 'Bom Jesus do Galho', 'Minas Gerais', None, None, None, None, None)
# (59587, 59587, '2021-07-14', 'Entre 22 a 27 anos', 'Juru', 'Paraíba', None, None, None, None, None)
# (20622, 20622, '2019-04-14', 'Entre 10 a 15 anos', 'Paula Freitas', 'Paraná', None, None, None, None, None)
# (5408, 5408, '2020-05-07', 'Entre 22 a 27 anos', 'Santa Maria das Barreiras', 'Pará', None, None, None, None, None)
# (93080, 93080, '2018-12-21', 'Mais de 70 anos', 'Várzea da Roça', 'Bahia', None, None, None, None, None)
# (16058, 16058, '2020-07-22', 'Entre 37 a 49 anos', 'São José do Divino', 'Minas Gerais', None, None, None, None, None)
# (96756, 96756, '2020-02-12', 'Entre 16 a 21 anos', 'Dumont', 'São Paulo', None, None, None, None, None)
# (92796, 92796, '2019-04-22', 'Entre 16 a 21 anos', 'Santa Tereza do Oeste', 'Paraná', None, None, None, None, None)
# (86648, 86648, '2020-11-11', 'Entre 28 a 36 anos', 'Uruoca', 'Ceará', None, None, None, None, None)
# (49936, 49936, '2019-08-08', 'Entre 16 a 21 anos', 'Camalaú', 'Paraíba', None, None, None, None, None)
# (16243, 16243, '2020-03-02', 'Entre 37 a 49 anos', 'Livramento de Nossa Senhora', 'Bahia', None, None, None, None, None)
# (14478, 14478, '2021-03-16', 'Entre 22 a 27 anos', 'Cachoeira Dourada', 'Goiás', None, None, None, None, None)
# (21152, 21152, '2021-05-08', 'Entre 28 a 36 anos', 'Pinhais', 'Paraná', None, None, None, None, None)
# (8258, 8258, '2018-10-09', 'Entre 50 a 61 anos', 'Posse', 'Goiás', None, None, None, None, None)
# (75856, 75856, '2019-11-27', 'Entre 16 a 21 anos', 'Ibituruna', 'Minas Gerais', None, None, None, None, None)
# (37904, 37904, '2019-02-21', 'Mais de 70 anos', 'Matelândia', 'Paraná', None, None, None, None, None)
# (62931, 62931, '2019-08-13', 'Entre 16 a 21 anos', 'Presidente Dutra', 'Maranhão', None, None, None, None, None)
# (3837, 3837, '2018-08-18', 'Mais de 70 anos', 'Campo Grande', 'Mato Grosso do Sul', None, None, None, None, None)
# (94531, 94531, '2020-06-14', 'Entre 10 a 15 anos', 'Barroquinha', 'Ceará', None, None, None, None, None)
# (68309, 68309, '2018-10-08', 'Mais de 70 anos', 'Campo Grande do Piauí', 'Piauí', None, None, None, None, None)
# (57231, 57231, '2018-02-09', 'Entre 50 a 61 anos', 'Conceição do Coité', 'Bahia', None, None, None, None, None)
# (78580, 78580, '2021-01-10', 'Entre 37 a 49 anos', 'Três Arroios', 'Rio Grande do Sul', None, None, None, None, None)
# (11056, 11056, '2021-04-15', 'Mais de 70 anos', 'São João do Carú', 'Maranhão', None, None, None, None, None)
# (83396, 83396, '2019-04-18', 'Entre 28 a 36 anos', 'Araioses', 'Maranhão', None, None, None, None, None)
# (74632, 74632, '2021-02-28', 'Entre 16 a 21 anos', 'Andirá', 'Paraná', None, None, None, None, None)
# (81258, 81258, '2019-09-19', 'Mais de 70 anos', 'Belo Campo', 'Bahia', None, None, None, None, None)
# (52615, 52615, '2018-05-31', 'Entre 22 a 27 anos', 'Juarina', 'Tocantins', None, None, None, None, None)
# (29862, 29862, '2020-02-17', 'Entre 28 a 36 anos', 'Indianópolis', 'Minas Gerais', None, None, None, None, None)
# (86384, 86384, '2018-12-05', 'Entre 62 a 70 anos', 'Sertanópolis', 'Paraná', None, None, None, None, None)
# (14355, 14355, '2018-01-06', 'Entre 28 a 36 anos', 'Ipecaetá', 'Bahia', None, None, None, None, None)
# (41788, 41788, '2019-09-13', 'Entre 16 a 21 anos', 'Capivari', 'São Paulo', None, None, None, None, None)
# (46927, 46927, '2018-07-15', 'Entre 50 a 61 anos', 'Nova Santa Rosa', 'Paraná', None, None, None, None, None)
# (22521, 22521, '2018-04-15', 'Entre 50 a 61 anos', 'São Bernardino', 'Santa Catarina', None, None, None, None, None)
# (40349, 40349, '2019-02-26', 'Entre 22 a 27 anos', 'Careiro', 'Amazonas', None, None, None, None, None)
# (82189, 82189, '2020-07-29', 'Entre 22 a 27 anos', 'Divino de São Lourenço', 'Espírito Santo', None, None, None, None, None)
# (24066, 24066, '2019-03-30', 'Entre 28 a 36 anos', 'Ponta Grossa', 'Paraná', None, None, None, None, None)
# (9805, 9805, '2021-06-29', 'Entre 62 a 70 anos', 'Itinga', 'Minas Gerais', None, None, None, None, None)
# (38495, 38495, '2018-11-14', 'Entre 50 a 61 anos', 'Areia Branca', 'Sergipe', None, None, None, None, None)
# (4251, 4251, '2018-03-16', 'Entre 10 a 15 anos', 'São Geraldo do Baixio', 'Minas Gerais', None, None, None, None, None)
# (81652, 81652, '2018-12-02', 'Entre 62 a 70 anos', 'Crisópolis', 'Bahia', None, None, None, None, None)
# (20293, 20293, '2019-12-06', 'Entre 50 a 61 anos', 'Cipotânea', 'Minas Gerais', None, None, None, None, None)
# (63336, 63336, '2018-07-28', 'Entre 10 a 15 anos', 'Matinha', 'Maranhão', None, None, None, None, None)
# (11199, 11199, '2021-05-06', 'Mais de 70 anos', 'Marília', 'São Paulo', None, None, None, None, None)
# (32634, 32634, '2019-07-29', 'Entre 50 a 61 anos', 'Paraíso', 'Santa Catarina', None, None, None, None, None)
# (51832, 51832, '2020-09-29', 'Entre 50 a 61 anos', 'Irituia', 'Pará', None, None, None, None, None)
# (88187, 88187, '2021-05-19', 'Entre 10 a 15 anos', 'Teixeirópolis', 'Rondônia', None, None, None, None, None)
# (45906, 45906, '2018-04-18', 'Entre 10 a 15 anos', 'Diamantino', 'Mato Grosso', None, None, None, None, None)
# (35330, 35330, '2019-12-09', 'Mais de 70 anos', 'Porto Alegre do Tocantins', 'Tocantins', None, None, None, None, None)
# (11426, 11426, '2020-12-05', 'Entre 16 a 21 anos', 'Barro Duro', 'Piauí', None, None, None, None, None)
# (40305, 40305, '2018-11-06', 'Entre 22 a 27 anos', 'Córrego Fundo', 'Minas Gerais', None, None, None, None, None)
# (34571, 34571, '2020-12-25', 'Entre 10 a 15 anos', 'Ibiam', 'Santa Catarina', None, None, None, None, None)
# (97405, 97405, '2018-02-11', 'Entre 22 a 27 anos', 'Porto Velho', 'Rondônia', None, None, None, None, None)
# (35183, 35183, '2019-05-31', 'Entre 22 a 27 anos', 'Barão', 'Rio Grande do Sul', None, None, None, None, None)
# (22360, 22360, '2020-11-13', 'Mais de 70 anos', 'Bom Retiro', 'Santa Catarina', None, None, None, None, None)
# (7546, 7546, '2020-04-23', 'Entre 22 a 27 anos', 'Horizonte', 'Ceará', None, None, None, None, None)
# (66468, 66468, '2018-08-10', 'Mais de 70 anos', 'Areal', 'Rio de Janeiro', None, None, None, None, None)
# (85387, 85387, '2020-01-25', 'Entre 10 a 15 anos', 'Diamante do Sul', 'Paraná', None, None, None, None, None)
# (20410, 20410, '2020-08-09', 'Entre 28 a 36 anos', 'Igaci', 'Alagoas', None, None, None, None, None)
# (50509, 50509, '2020-09-27', 'Entre 28 a 36 anos', 'Mata', 'Rio Grande do Sul', None, None, None, None, None)
# (85250, 85250, '2020-11-24', 'Entre 10 a 15 anos', 'Buenos Aires', 'Pernambuco', None, None, None, None, None)
# (62096, 62096, '2019-03-18', 'Mais de 70 anos', 'Canápolis', 'Minas Gerais', None, None, None, None, None)
# (6110, 6110, '2018-07-26', 'Entre 22 a 27 anos', 'Poção', 'Pernambuco', None, None, None, None, None)
# (63192, 63192, '2021-01-19', 'Entre 16 a 21 anos', 'Apodi', 'Rio Grande do Norte', None, None, None, None, None)
# (23847, 23847, '2019-08-09', 'Entre 16 a 21 anos', 'Central de Minas', 'Minas Gerais', None, None, None, None, None)
# (83858, 83858, '2018-08-22', 'Entre 28 a 36 anos', 'Caraúbas do Piauí', 'Piauí', None, None, None, None, None)
# (19417, 19417, '2020-06-20', 'Entre 16 a 21 anos', 'Cerquilho', 'São Paulo', None, None, None, None, None)
# (51663, 51663, '2021-05-28', 'Entre 22 a 27 anos', 'Formosa do Sul', 'Santa Catarina', None, None, None, None, None)
# (32860, 32860, '2021-03-17', 'Entre 37 a 49 anos', 'Cássia dos Coqueiros', 'São Paulo', None, None, None, None, None)
